# %% [markdown]
# ### COVID-19: Predicting unreported infection rate across U.S. counties
# Data source <br>
# 1) https://data.census.gov/cedsci/ <br>
# 2) https://coronavirus.jhu.edu/

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # PART 1: Population

# %%
data = pd.read_csv('pop.csv')

# %%
data
# Out:
#                  uid           county          state  population
# 0     0500000US01001   Autauga County        Alabama       55200
# 1     0500000US01003   Baldwin County        Alabama      208107
# 2     0500000US01005   Barbour County        Alabama       25782
# 3     0500000US01007      Bibb County        Alabama       22527
# 4     0500000US01009    Blount County        Alabama       57645
# ...              ...              ...            ...         ...
# 3216  0500000US31113     Logan County       Nebraska         886
# 3217  0500000US31171    Thomas County       Nebraska         645
# 3218  0500000US30033  Garfield County        Montana        1141
# 3219  0500000US38065    Oliver County   North Dakota        1837
# 3220       0100000US    United States            NaN   322903030
#
# [3221 rows x 4 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3221 entries, 0 to 3220
# Data columns (total 4 columns):
# uid           3221 non-null object
# county        3221 non-null object
# state         3220 non-null object
# population    3221 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 100.8+ KB

# %%
data.loc[3220,'state'] = 'United States'
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3221 entries, 0 to 3220
# Data columns (total 4 columns):
# uid           3221 non-null object
# county        3221 non-null object
# state         3221 non-null object
# population    3221 non-null int64
# dtypes: int64(1), object(3)
# memory usage: 100.8+ KB

# %%
data.to_csv('us_pop_2018.csv')

# %% [markdown]
# # PART 2: Age & Gender

# %%
df = pd.read_csv('age_sex.csv')

# %%
df.columns
# Out:
# Index(['GEO_ID', 'NAME', 'S0101_C01_001E', 'S0101_C01_001M', 'S0101_C02_001E',
#        'S0101_C02_001M', 'S0101_C03_001E', 'S0101_C03_001M', 'S0101_C04_001E',
#        'S0101_C04_001M',
#        ...
#        'S0101_C02_038E', 'S0101_C02_038M', 'S0101_C03_038E', 'S0101_C03_038M',
#        'S0101_C04_038E', 'S0101_C04_038M', 'S0101_C05_038E', 'S0101_C05_038M',
#        'S0101_C06_038E', 'S0101_C06_038M'],
#       dtype='object', length=458)

# %%
df.head()
# Out:
#            GEO_ID                     NAME                     S0101_C01_001E  \
# 0              id     Geographic Area Name  Estimate!!Total!!Total population
# 1  0500000US01001  Autauga County, Alabama                              55200
# 2  0500000US01003  Baldwin County, Alabama                             208107
# 3  0500000US01005  Barbour County, Alabama                              25782
# 4  0500000US01007     Bibb County, Alabama                              22527
#
#                                  S0101_C01_001M  \
# 0  Margin of Error!!Total MOE!!Total population
# 1                                         *****
# 2                                         *****
# 3                                         *****
# 4                                         *****
#
#                         S0101_C02_001E  \
# 0  Estimate!!Percent!!Total population
# 1                                  (X)
# 2                                  (X)
# 3                                  (X)
# 4                                  (X)
#
#                                    S0101_C02_001M  \
# 0  Margin of Error!!Percent MOE!!Total population
# 1                                             (X)
# 2                                             (X)
# 3                                             (X)
# 4                                             (X)
#
#                      S0101_C03_001E  \
# 0  Estimate!!Male!!Total population
# 1                             26874
# 2                            101188
# 3                             13697
# 4                             12152
#
#                                 S0101_C03_001M  \
# 0  Margin of Error!!Male MOE!!Total population
# 1                                          147
# 2                                          242
# 3                                           71
# 4                                          180
#
#                              S0101_C04_001E  \
# 0  Estimate!!Percent Male!!Total population
# 1                                       (X)
# 2                                       (X)
# 3                                       (X)
# 4                                       (X)
#
#                                       S0101_C04_001M  ...  \
# 0  Margin of Error!!Percent Male MOE!!Total popul...  ...
# 1                                                (X)  ...
# 2                                                (X)  ...
# 3                                                (X)  ...
# 4                                                (X)  ...
#
#                               S0101_C02_038E  \
# 0  Estimate!!Percent!!PERCENT ALLOCATED!!Age
# 1                                        1.3
# 2                                        1.8
# 3                                        0.9
# 4                                        8.2
#
#                                       S0101_C02_038M  \
# 0  Margin of Error!!Percent MOE!!PERCENT ALLOCATE...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                            S0101_C03_038E  \
# 0  Estimate!!Male!!PERCENT ALLOCATED!!Age
# 1                                     (X)
# 2                                     (X)
# 3                                     (X)
# 4                                     (X)
#
#                                       S0101_C03_038M  \
# 0  Margin of Error!!Male MOE!!PERCENT ALLOCATED!!Age
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                    S0101_C04_038E  \
# 0  Estimate!!Percent Male!!PERCENT ALLOCATED!!Age
# 1                                             (X)
# 2                                             (X)
# 3                                             (X)
# 4                                             (X)
#
#                                       S0101_C04_038M  \
# 0  Margin of Error!!Percent Male MOE!!PERCENT ALL...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                              S0101_C05_038E  \
# 0  Estimate!!Female!!PERCENT ALLOCATED!!Age
# 1                                       (X)
# 2                                       (X)
# 3                                       (X)
# 4                                       (X)
#
#                                       S0101_C05_038M  \
# 0  Margin of Error!!Female MOE!!PERCENT ALLOCATED...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
#                                      S0101_C06_038E  \
# 0  Estimate!!Percent Female!!PERCENT ALLOCATED!!Age
# 1                                               (X)
# 2                                               (X)
# 3                                               (X)
# 4                                               (X)
#
#                                       S0101_C06_038M
# 0  Margin of Error!!Percent Female MOE!!PERCENT A...
# 1                                                (X)
# 2                                                (X)
# 3                                                (X)
# 4                                                (X)
#
# [5 rows x 458 columns]

# %%
meta = pd.read_csv('agesex_meta.csv')

# %%
meta
# Out:
#              GEO_ID                                                 id  \
# 0              NAME                               Geographic Area Name
# 1    S0101_C01_001E                  Estimate!!Total!!Total population
# 2    S0101_C01_001M       Margin of Error!!Total MOE!!Total population
# 3    S0101_C01_002E  Estimate!!Total!!Total population!!AGE!!Under ...
# 4    S0101_C01_002M  Margin of Error!!Total MOE!!Total population!!...
# ..              ...                                                ...
# 452  S0101_C06_036M  Margin of Error!!Percent Female MOE!!Total pop...
# 453  S0101_C06_037E   Estimate!!Percent Female!!PERCENT ALLOCATED!!Sex
# 454  S0101_C06_037M  Margin of Error!!Percent Female MOE!!PERCENT A...
# 455  S0101_C06_038E   Estimate!!Percent Female!!PERCENT ALLOCATED!!Age
# 456  S0101_C06_038M  Margin of Error!!Percent Female MOE!!PERCENT A...
#
#      Unnamed: 2
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 452         NaN
# 453         NaN
# 454         NaN
# 455         NaN
# 456         NaN
#
# [457 rows x 3 columns]

# %%
df.iloc[0].unique()
# Out:
# array(['id', 'Geographic Area Name', 'Estimate!!Total!!Total population',
#        'Margin of Error!!Total MOE!!Total population',
#        'Estimate!!Percent!!Total population',
#        'Margin of Error!!Percent MOE!!Total population',
#        'Estimate!!Male!!Total population',
#        'Margin of Error!!Male MOE!!Total population',
#        'Estimate!!Percent Male!!Total population',
#        'Margin of Error!!Percent Male MOE!!Total population',
#        'Estimate!!Female!!Total population',
#        'Margin of Error!!Female MOE!!Total population',
#        'Estimate!!Percent Female!!Total population',
#        'Margin of Error!!Percent Female MOE!!Total population',
#        'Estimate!!Total!!Total population!!AGE!!Under 5 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!Under 5 years',
#        'Estimate!!Percent!!Total population!!AGE!!Under 5 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!Under 5 years',
#        'Estimate!!Male!!Total population!!AGE!!Under 5 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!Under 5 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!Under 5 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!Under 5 years',
#        'Estimate!!Female!!Total population!!AGE!!Under 5 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!Under 5 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!Under 5 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!Under 5 years',
#        'Estimate!!Total!!Total population!!AGE!!5 to 9 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!5 to 9 years',
#        'Estimate!!Percent!!Total population!!AGE!!5 to 9 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!5 to 9 years',
#        'Estimate!!Male!!Total population!!AGE!!5 to 9 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!5 to 9 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!5 to 9 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!5 to 9 years',
#        'Estimate!!Female!!Total population!!AGE!!5 to 9 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!5 to 9 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!5 to 9 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!5 to 9 years',
#        'Estimate!!Total!!Total population!!AGE!!10 to 14 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!10 to 14 years',
#        'Estimate!!Percent!!Total population!!AGE!!10 to 14 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!10 to 14 years',
#        'Estimate!!Male!!Total population!!AGE!!10 to 14 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!10 to 14 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!10 to 14 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!10 to 14 years',
#        'Estimate!!Female!!Total population!!AGE!!10 to 14 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!10 to 14 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!10 to 14 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!10 to 14 years',
#        'Estimate!!Total!!Total population!!AGE!!15 to 19 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!15 to 19 years',
#        'Estimate!!Percent!!Total population!!AGE!!15 to 19 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!15 to 19 years',
#        'Estimate!!Male!!Total population!!AGE!!15 to 19 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!15 to 19 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!15 to 19 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!15 to 19 years',
#        'Estimate!!Female!!Total population!!AGE!!15 to 19 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!15 to 19 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!15 to 19 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!15 to 19 years',
#        'Estimate!!Total!!Total population!!AGE!!20 to 24 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!20 to 24 years',
#        'Estimate!!Percent!!Total population!!AGE!!20 to 24 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!20 to 24 years',
#        'Estimate!!Male!!Total population!!AGE!!20 to 24 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!20 to 24 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!20 to 24 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!20 to 24 years',
#        'Estimate!!Female!!Total population!!AGE!!20 to 24 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!20 to 24 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!20 to 24 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!20 to 24 years',
#        'Estimate!!Total!!Total population!!AGE!!25 to 29 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!25 to 29 years',
#        'Estimate!!Percent!!Total population!!AGE!!25 to 29 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!25 to 29 years',
#        'Estimate!!Male!!Total population!!AGE!!25 to 29 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!25 to 29 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!25 to 29 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!25 to 29 years',
#        'Estimate!!Female!!Total population!!AGE!!25 to 29 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!25 to 29 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!25 to 29 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!25 to 29 years',
#        'Estimate!!Total!!Total population!!AGE!!30 to 34 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!30 to 34 years',
#        'Estimate!!Percent!!Total population!!AGE!!30 to 34 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!30 to 34 years',
#        'Estimate!!Male!!Total population!!AGE!!30 to 34 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!30 to 34 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!30 to 34 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!30 to 34 years',
#        'Estimate!!Female!!Total population!!AGE!!30 to 34 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!30 to 34 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!30 to 34 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!30 to 34 years',
#        'Estimate!!Total!!Total population!!AGE!!35 to 39 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!35 to 39 years',
#        'Estimate!!Percent!!Total population!!AGE!!35 to 39 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!35 to 39 years',
#        'Estimate!!Male!!Total population!!AGE!!35 to 39 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!35 to 39 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!35 to 39 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!35 to 39 years',
#        'Estimate!!Female!!Total population!!AGE!!35 to 39 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!35 to 39 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!35 to 39 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!35 to 39 years',
#        'Estimate!!Total!!Total population!!AGE!!40 to 44 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!40 to 44 years',
#        'Estimate!!Percent!!Total population!!AGE!!40 to 44 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!40 to 44 years',
#        'Estimate!!Male!!Total population!!AGE!!40 to 44 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!40 to 44 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!40 to 44 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!40 to 44 years',
#        'Estimate!!Female!!Total population!!AGE!!40 to 44 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!40 to 44 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!40 to 44 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!40 to 44 years',
#        'Estimate!!Total!!Total population!!AGE!!45 to 49 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!45 to 49 years',
#        'Estimate!!Percent!!Total population!!AGE!!45 to 49 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!45 to 49 years',
#        'Estimate!!Male!!Total population!!AGE!!45 to 49 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!45 to 49 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!45 to 49 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!45 to 49 years',
#        'Estimate!!Female!!Total population!!AGE!!45 to 49 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!45 to 49 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!45 to 49 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!45 to 49 years',
#        'Estimate!!Total!!Total population!!AGE!!50 to 54 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!50 to 54 years',
#        'Estimate!!Percent!!Total population!!AGE!!50 to 54 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!50 to 54 years',
#        'Estimate!!Male!!Total population!!AGE!!50 to 54 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!50 to 54 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!50 to 54 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!50 to 54 years',
#        'Estimate!!Female!!Total population!!AGE!!50 to 54 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!50 to 54 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!50 to 54 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!50 to 54 years',
#        'Estimate!!Total!!Total population!!AGE!!55 to 59 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!55 to 59 years',
#        'Estimate!!Percent!!Total population!!AGE!!55 to 59 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!55 to 59 years',
#        'Estimate!!Male!!Total population!!AGE!!55 to 59 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!55 to 59 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!55 to 59 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!55 to 59 years',
#        'Estimate!!Female!!Total population!!AGE!!55 to 59 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!55 to 59 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!55 to 59 years',
#        'Estimate!!Total!!Total population!!AGE!!60 to 64 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!60 to 64 years',
#        'Estimate!!Percent!!Total population!!AGE!!60 to 64 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!60 to 64 years',
#        'Estimate!!Male!!Total population!!AGE!!60 to 64 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!60 to 64 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!60 to 64 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!60 to 64 years',
#        'Estimate!!Female!!Total population!!AGE!!60 to 64 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!60 to 64 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!55 to 59 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!60 to 64 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!60 to 64 years',
#        'Estimate!!Total!!Total population!!AGE!!65 to 69 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!65 to 69 years',
#        'Estimate!!Percent!!Total population!!AGE!!65 to 69 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!65 to 69 years',
#        'Estimate!!Male!!Total population!!AGE!!65 to 69 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!65 to 69 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!65 to 69 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!65 to 69 years',
#        'Estimate!!Female!!Total population!!AGE!!65 to 69 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!65 to 69 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!65 to 69 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!65 to 69 years',
#        'Estimate!!Total!!Total population!!AGE!!70 to 74 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!70 to 74 years',
#        'Estimate!!Percent!!Total population!!AGE!!70 to 74 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!70 to 74 years',
#        'Estimate!!Male!!Total population!!AGE!!70 to 74 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!70 to 74 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!70 to 74 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!70 to 74 years',
#        'Estimate!!Female!!Total population!!AGE!!70 to 74 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!70 to 74 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!70 to 74 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!70 to 74 years',
#        'Estimate!!Total!!Total population!!AGE!!75 to 79 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!75 to 79 years',
#        'Estimate!!Percent!!Total population!!AGE!!75 to 79 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!75 to 79 years',
#        'Estimate!!Male!!Total population!!AGE!!75 to 79 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!75 to 79 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!75 to 79 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!75 to 79 years',
#        'Estimate!!Female!!Total population!!AGE!!75 to 79 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!75 to 79 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!75 to 79 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!75 to 79 years',
#        'Estimate!!Total!!Total population!!AGE!!80 to 84 years',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!80 to 84 years',
#        'Estimate!!Percent!!Total population!!AGE!!80 to 84 years',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!80 to 84 years',
#        'Estimate!!Male!!Total population!!AGE!!80 to 84 years',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!80 to 84 years',
#        'Estimate!!Percent Male!!Total population!!AGE!!80 to 84 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!80 to 84 years',
#        'Estimate!!Female!!Total population!!AGE!!80 to 84 years',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!80 to 84 years',
#        'Estimate!!Percent Female!!Total population!!AGE!!80 to 84 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!80 to 84 years',
#        'Estimate!!Total!!Total population!!AGE!!85 years and over',
#        'Margin of Error!!Total MOE!!Total population!!AGE!!85 years and over',
#        'Estimate!!Percent!!Total population!!AGE!!85 years and over',
#        'Margin of Error!!Percent MOE!!Total population!!AGE!!85 years and over',
#        'Estimate!!Male!!Total population!!AGE!!85 years and over',
#        'Margin of Error!!Male MOE!!Total population!!AGE!!85 years and over',
#        'Estimate!!Percent Male!!Total population!!AGE!!85 years and over',
#        'Margin of Error!!Percent Male MOE!!Total population!!AGE!!85 years and over',
#        'Estimate!!Female!!Total population!!AGE!!85 years and over',
#        'Margin of Error!!Female MOE!!Total population!!AGE!!85 years and over',
#        'Estimate!!Percent Female!!Total population!!AGE!!85 years and over',
#        'Margin of Error!!Percent Female MOE!!Total population!!AGE!!85 years and over',
#        'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#        'Margin of Error!!Total MOE!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#        'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#        'Margin of Error!!Percent MOE!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#        'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#        'Margin of Error!!Male MOE!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#        'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#        'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#        'Margin of Error!!Female MOE!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#        'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!SELECTED AGE CATEGORIES!!5 to 14 years',
#        'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#        'Margin of Error!!Total MOE!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#        'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#        'Margin of Error!!Percent MOE!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#        'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#        'Margin of Error!!Male MOE!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#        'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#        'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#        'Margin of Error!!Female MOE!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#        'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!SELECTED AGE CATEGORIES!!15 to 17 years',
#        'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#        'Margin of Error!!Total MOE!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#        'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#        'Margin of Error!!Percent MOE!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#        'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#        'Margin of Error!!Male MOE!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#        'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#        'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#        'Margin of Error!!Female MOE!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#        'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!SELECTED AGE CATEGORIES!!Under 18 years',
#        'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#        'Margin of Error!!Total MOE!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#        'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#        'Margin of Error!!Percent MOE!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#        'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#        'Margin of Error!!Male MOE!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#        'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#        'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#        'Margin of Error!!Female MOE!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#        'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!SELECTED AGE CATEGORIES!!18 to 24 years',
#        'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#        'Margin of Error!!Total MOE!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#        'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#        'Margin of Error!!Percent MOE!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#        'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#        'Margin of Error!!Male MOE!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#        'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#        'Margin of Error!!Percent Male MOE!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#        'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#        'Margin of Error!!Female MOE!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#        'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#        'Margin of Error!!Percent Female MOE!!Total population!!SELECTED AGE CATEGORIES!!15 to 44 years',
#        'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#        'Margin of Error!!Total MOE!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#        'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#        'Margin of Error!!Percent MOE!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#        'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#        'Margin of Error!!Male MOE!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#        'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#        'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#        'Margin of Error!!Female MOE!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#        'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#        'Margin of Error!!Percent Female MOE!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#        'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#        'Margin of Error!!Total MOE!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#        'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#        'Margin of Error!!Percent MOE!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#        'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#        'Margin of Error!!Male MOE!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#        'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#        'Margin of Error!!Percent Male MOE!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#        'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#        'Margin of Error!!Female MOE!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#        'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#        'Margin of Error!!Percent Female MOE!!Total population!!SELECTED AGE CATEGORIES!!18 years and over',
#        'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#        'Margin of Error!!Total MOE!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#        'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#        'Margin of Error!!Percent MOE!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#        'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#        'Margin of Error!!Male MOE!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#        'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#        'Margin of Error!!Percent Male MOE!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#        'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#        'Margin of Error!!Female MOE!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#        'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#        'Margin of Error!!Percent Female MOE!!Total population!!SELECTED AGE CATEGORIES!!21 years and over',
#        'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#        'Margin of Error!!Total MOE!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#        'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#        'Margin of Error!!Percent MOE!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#        'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#        'Margin of Error!!Male MOE!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#        'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#        'Margin of Error!!Percent Male MOE!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#        'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#        'Margin of Error!!Female MOE!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#        'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#        'Margin of Error!!Percent Female MOE!!Total population!!SELECTED AGE CATEGORIES!!60 years and over',
#        'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#        'Margin of Error!!Total MOE!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#        'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#        'Margin of Error!!Percent MOE!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#        'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#        'Margin of Error!!Male MOE!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#        'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#        'Margin of Error!!Percent Male MOE!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#        'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#        'Margin of Error!!Female MOE!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#        'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#        'Margin of Error!!Percent Female MOE!!Total population!!SELECTED AGE CATEGORIES!!62 years and over',
#        'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#        'Margin of Error!!Total MOE!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#        'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#        'Margin of Error!!Percent MOE!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#        'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#        'Margin of Error!!Male MOE!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#        'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#        'Margin of Error!!Percent Male MOE!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#        'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#        'Margin of Error!!Female MOE!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#        'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#        'Margin of Error!!Percent Female MOE!!Total population!!SELECTED AGE CATEGORIES!!65 years and over',
#        'Estimate!!Total!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#        'Margin of Error!!Total MOE!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#        'Estimate!!Percent!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#        'Margin of Error!!Percent MOE!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#        'Estimate!!Male!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#        'Margin of Error!!Male MOE!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#        'Estimate!!Percent Male!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#        'Margin of Error!!Percent Male MOE!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#        'Estimate!!Female!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#        'Margin of Error!!Female MOE!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#        'Estimate!!Percent Female!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#        'Margin of Error!!Percent Female MOE!!Total population!!SELECTED AGE CATEGORIES!!75 years and over',
#        'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#        'Margin of Error!!Total MOE!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#        'Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#        'Margin of Error!!Percent MOE!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#        'Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#        'Margin of Error!!Male MOE!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#        'Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#        'Margin of Error!!Percent Male MOE!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#        'Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#        'Margin of Error!!Female MOE!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#        'Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#        'Margin of Error!!Percent Female MOE!!Total population!!SUMMARY INDICATORS!!Median age (years)',
#        'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#        'Margin of Error!!Total MOE!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#        'Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#        'Margin of Error!!Percent Male MOE!!Total population!!SELECTED AGE CATEGORIES!!16 years and over',
#        'Margin of Error!!Percent MOE!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#        'Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#        'Margin of Error!!Male MOE!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#        'Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#        'Margin of Error!!Percent Male MOE!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#        'Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#        'Margin of Error!!Female MOE!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#        'Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#        'Margin of Error!!Percent Female MOE!!Total population!!SUMMARY INDICATORS!!Sex ratio (males per 100 females)',
#        'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#        'Margin of Error!!Total MOE!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#        'Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#        'Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#        'Margin of Error!!Female MOE!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#        'Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#        'Margin of Error!!Percent Female MOE!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#        'Estimate!!Total!!PERCENT ALLOCATED!!Sex',
#        'Margin of Error!!Total MOE!!PERCENT ALLOCATED!!Sex',
#        'Estimate!!Percent!!PERCENT ALLOCATED!!Sex',
#        'Margin of Error!!Percent MOE!!PERCENT ALLOCATED!!Sex',
#        'Estimate!!Male!!PERCENT ALLOCATED!!Sex',
#        'Margin of Error!!Male MOE!!PERCENT ALLOCATED!!Sex',
#        'Estimate!!Percent Male!!PERCENT ALLOCATED!!Sex',
#        'Margin of Error!!Percent Male MOE!!PERCENT ALLOCATED!!Sex',
#        'Margin of Error!!Percent MOE!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#        'Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#        'Margin of Error!!Male MOE!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#        'Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#        'Margin of Error!!Percent Male MOE!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#        'Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#        'Margin of Error!!Female MOE!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#        'Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#        'Margin of Error!!Percent Female MOE!!Total population!!SUMMARY INDICATORS!!Age dependency ratio',
#        'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#        'Margin of Error!!Total MOE!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#        'Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#        'Margin of Error!!Percent MOE!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#        'Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#        'Margin of Error!!Male MOE!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#        'Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#        'Margin of Error!!Percent Male MOE!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#        'Estimate!!Female!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#        'Margin of Error!!Female MOE!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#        'Estimate!!Percent Female!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#        'Margin of Error!!Percent Female MOE!!Total population!!SUMMARY INDICATORS!!Old-age dependency ratio',
#        'Estimate!!Total!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#        'Margin of Error!!Total MOE!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#        'Estimate!!Percent!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#        'Margin of Error!!Percent MOE!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#        'Estimate!!Male!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#        'Margin of Error!!Male MOE!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#        'Estimate!!Percent Male!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#        'Margin of Error!!Percent Male MOE!!Total population!!SUMMARY INDICATORS!!Child dependency ratio',
#        'Estimate!!Female!!PERCENT ALLOCATED!!Sex',
#        'Margin of Error!!Female MOE!!PERCENT ALLOCATED!!Sex',
#        'Estimate!!Percent Female!!PERCENT ALLOCATED!!Sex',
#        'Margin of Error!!Percent Female MOE!!PERCENT ALLOCATED!!Sex',
#        'Estimate!!Total!!PERCENT ALLOCATED!!Age',
#        'Margin of Error!!Total MOE!!PERCENT ALLOCATED!!Age',
#        'Estimate!!Percent!!PERCENT ALLOCATED!!Age',
#        'Margin of Error!!Percent MOE!!PERCENT ALLOCATED!!Age',
#        'Estimate!!Male!!PERCENT ALLOCATED!!Age',
#        'Margin of Error!!Male MOE!!PERCENT ALLOCATED!!Age',
#        'Estimate!!Percent Male!!PERCENT ALLOCATED!!Age',
#        'Margin of Error!!Percent Male MOE!!PERCENT ALLOCATED!!Age',
#        'Estimate!!Female!!PERCENT ALLOCATED!!Age',
#        'Margin of Error!!Female MOE!!PERCENT ALLOCATED!!Age',
#        'Estimate!!Percent Female!!PERCENT ALLOCATED!!Age',
#        'Margin of Error!!Percent Female MOE!!PERCENT ALLOCATED!!Age'],
#       dtype=object)

# %%
#https://www.worldometers.info/coronavirus/coronavirus-age-sex-demographics/

# %%
use = ['id','Estimate!!Total!!Total population','Geographic Area Name',
       'Estimate!!Male!!Total population','Estimate!!Female!!Total population',
       'Estimate!!Percent!!Total population!!AGE!!15 to 19 years',
       'Estimate!!Percent!!Total population!!AGE!!20 to 24 years',
      'Estimate!!Percent!!Total population!!AGE!!25 to 29 years','Estimate!!Percent!!Total population!!AGE!!30 to 34 years',
      'Estimate!!Percent!!Total population!!AGE!!35 to 39 years','Estimate!!Percent!!Total population!!AGE!!40 to 44 years',
      'Estimate!!Percent!!Total population!!AGE!!45 to 49 years','Estimate!!Percent!!Total population!!AGE!!50 to 54 years',
     'Estimate!!Percent!!Total population!!AGE!!55 to 59 years', 'Estimate!!Percent!!Total population!!AGE!!60 to 64 years',
      'Estimate!!Percent!!Total population!!AGE!!65 to 69 years','Estimate!!Percent!!Total population!!AGE!!70 to 74 years',
      'Estimate!!Percent!!Total population!!AGE!!75 to 79 years','Estimate!!Percent!!Total population!!AGE!!80 to 84 years',
      'Estimate!!Percent!!Total population!!AGE!!85 years and over']

# %%
usecol = meta[meta['id'].isin(use)]['GEO_ID'].to_list()
usecol.append('GEO_ID')

# %%
usecol
# Out:
# ['NAME',
#  'S0101_C01_001E',
#  'S0101_C02_005E',
#  'S0101_C02_006E',
#  'S0101_C02_007E',
#  'S0101_C02_008E',
#  'S0101_C02_009E',
#  'S0101_C02_010E',
#  'S0101_C02_011E',
#  'S0101_C02_012E',
#  'S0101_C02_013E',
#  'S0101_C02_014E',
#  'S0101_C02_015E',
#  'S0101_C02_016E',
#  'S0101_C02_017E',
#  'S0101_C02_018E',
#  'S0101_C02_019E',
#  'S0101_C03_001E',
#  'S0101_C05_001E',
#  'GEO_ID']

# %%
data2 = df[usecol]
data2.head()
# Out:
#                       NAME                     S0101_C01_001E  \
# 0     Geographic Area Name  Estimate!!Total!!Total population
# 1  Autauga County, Alabama                              55200
# 2  Baldwin County, Alabama                             208107
# 3  Barbour County, Alabama                              25782
# 4     Bibb County, Alabama                              22527
#
#                                       S0101_C02_005E  \
# 0  Estimate!!Percent!!Total population!!AGE!!15 t...
# 1                                                7.0
# 2                                                6.1
# 3                                                5.6
# 4                                                6.7
#
#                                       S0101_C02_006E  \
# 0  Estimate!!Percent!!Total population!!AGE!!20 t...
# 1                                                6.0
# 2                                                5.2
# 3                                                6.4
# 4                                                6.6
#
#                                       S0101_C02_007E  \
# 0  Estimate!!Percent!!Total population!!AGE!!25 t...
# 1                                                6.6
# 2                                                5.7
# 3                                                7.2
# 4                                                6.9
#
#                                       S0101_C02_008E  \
# 0  Estimate!!Percent!!Total population!!AGE!!30 t...
# 1                                                6.2
# 2                                                5.5
# 3                                                7.0
# 4                                                6.7
#
#                                       S0101_C02_009E  \
# 0  Estimate!!Percent!!Total population!!AGE!!35 t...
# 1                                                7.4
# 2                                                6.0
# 3                                                6.4
# 4                                                6.5
#
#                                       S0101_C02_010E  \
# 0  Estimate!!Percent!!Total population!!AGE!!40 t...
# 1                                                5.9
# 2                                                6.2
# 3                                                5.6
# 4                                                6.4
#
#                                       S0101_C02_011E  \
# 0  Estimate!!Percent!!Total population!!AGE!!45 t...
# 1                                                7.0
# 2                                                6.6
# 3                                                6.5
# 4                                                8.0
#
#                                       S0101_C02_012E  \
# 0  Estimate!!Percent!!Total population!!AGE!!50 t...
# 1                                                7.2
# 2                                                7.0
# 3                                                6.9
# 4                                                7.2
#
#                                       S0101_C02_013E  \
# 0  Estimate!!Percent!!Total population!!AGE!!55 t...
# 1                                                7.5
# 2                                                6.9
# 3                                                6.4
# 4                                                6.6
#
#                                       S0101_C02_014E  \
# 0  Estimate!!Percent!!Total population!!AGE!!60 t...
# 1                                                4.9
# 2                                                7.1
# 3                                                6.4
# 4                                                5.4
#
#                                       S0101_C02_015E  \
# 0  Estimate!!Percent!!Total population!!AGE!!65 t...
# 1                                                4.1
# 2                                                6.3
# 3                                                5.9
# 4                                                5.7
#
#                                       S0101_C02_016E  \
# 0  Estimate!!Percent!!Total population!!AGE!!70 t...
# 1                                                4.4
# 2                                                5.5
# 3                                                5.1
# 4                                                3.7
#
#                                       S0101_C02_017E  \
# 0  Estimate!!Percent!!Total population!!AGE!!75 t...
# 1                                                2.7
# 2                                                3.5
# 3                                                3.3
# 4                                                2.8
#
#                                       S0101_C02_018E  \
# 0  Estimate!!Percent!!Total population!!AGE!!80 t...
# 1                                                1.9
# 2                                                2.3
# 3                                                2.1
# 4                                                2.2
#
#                                       S0101_C02_019E  \
# 0  Estimate!!Percent!!Total population!!AGE!!85 y...
# 1                                                1.5
# 2                                                1.9
# 3                                                1.6
# 4                                                1.9
#
#                      S0101_C03_001E                      S0101_C05_001E  \
# 0  Estimate!!Male!!Total population  Estimate!!Female!!Total population
# 1                             26874                               28326
# 2                            101188                              106919
# 3                             13697                               12085
# 4                             12152                               10375
#
#            GEO_ID
# 0              id
# 1  0500000US01001
# 2  0500000US01003
# 3  0500000US01005
# 4  0500000US01007

# %%
col_ = {'GEO_ID':'geo_id','NAME':'county','S0101_C01_001E':'population','S0101_C02_005E':'age15_19','S0101_C02_006E':'age20_24','S0101_C02_007E':'age25_29',
       'S0101_C02_008E':'age30_34', 'S0101_C02_009E':'35_39','S0101_C02_010E':'40_44','S0101_C02_011E':'45_49',
       'S0101_C02_012E':'50_54','S0101_C02_013E':'age55_59','S0101_C02_014E':'age60_64','S0101_C02_015E':'65_69',
       'S0101_C02_016E':'70_74','S0101_C02_017E':'75_79','S0101_C02_018E':'80_84','S0101_C02_019E':'85plus',
       'S0101_C05_001E':'total_female', 'S0101_C03_001E':'total_male'}

# %%
data2 = data2.rename(columns=col_)
data2 = data2[1:]
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3221 entries, 1 to 3221
# Data columns (total 20 columns):
# county          3221 non-null object
# population      3221 non-null object
# age15_19        3221 non-null object
# age20_24        3221 non-null object
# age25_29        3221 non-null object
# age30_34        3221 non-null object
# 35_39           3221 non-null object
# 40_44           3221 non-null object
# 45_49           3221 non-null object
# 50_54           3221 non-null object
# age55_59        3221 non-null object
# age60_64        3221 non-null object
# 65_69           3221 non-null object
# 70_74           3221 non-null object
# 75_79           3221 non-null object
# 80_84           3221 non-null object
# 85plus          3221 non-null object
# total_male      3221 non-null object
# total_female    3221 non-null object
# geo_id          3221 non-null object
# dtypes: object(20)
# memory usage: 503.4+ KB

# %%
datacol = data2.columns.to_list()
datacol = datacol[1:19]
datacol[1:16]
# Out:
# ['age15_19',
#  'age20_24',
#  'age25_29',
#  'age30_34',
#  '35_39',
#  '40_44',
#  '45_49',
#  '50_54',
#  'age55_59',
#  'age60_64',
#  '65_69',
#  '70_74',
#  '75_79',
#  '80_84',
#  '85plus']

# %%
data2[datacol] = data2[datacol].astype(float)
data2.describe()
# Out:
#          population     age15_19     age20_24     age25_29     age30_34  \
# count  3.221000e+03  3221.000000  3221.000000  3221.000000  3221.000000
# mean   2.015501e+05     6.474107     6.264204     5.960975     5.839305
# std    5.697087e+06     1.420987     2.374332     1.344846     1.111407
# min    7.500000e+01     0.000000     0.000000     0.400000     1.200000
# 25%    1.121500e+04     5.800000     5.200000     5.100000     5.200000
# 50%    2.599200e+04     6.400000     5.800000     5.800000     5.700000
# 75%    6.661300e+04     7.000000     6.700000     6.600000     6.400000
# max    3.229030e+08    26.400000    28.700000    14.300000    14.100000
#
#              35_39        40_44        45_49        50_54     age55_59  \
# count  3221.000000  3221.000000  3221.000000  3221.000000  3221.000000
# mean      5.845514     5.757467     6.103912     6.828966     7.250078
# std       1.030050     0.989798     0.883146     0.889795     1.262578
# min       0.000000     1.200000     0.000000     0.000000     1.700000
# 25%       5.200000     5.200000     5.600000     6.400000     6.600000
# 50%       5.800000     5.800000     6.100000     6.900000     7.200000
# 75%       6.400000     6.300000     6.600000     7.300000     7.900000
# max      10.400000    12.500000    11.800000    13.000000    26.700000
#
#           age60_64        65_69        70_74        75_79        80_84  \
# count  3221.000000  3221.000000  3221.000000  3221.000000  3221.000000
# mean      6.894008     5.959485     4.559640     3.314995     2.285129
# std       1.365781     1.462709     1.323269     1.052472     0.829263
# min       1.500000     1.500000     1.000000     0.200000     0.000000
# 25%       6.100000     5.000000     3.700000     2.600000     1.800000
# 50%       6.800000     5.800000     4.400000     3.200000     2.200000
# 75%       7.600000     6.600000     5.200000     3.900000     2.700000
# max      17.500000    17.200000    16.800000    11.100000    10.200000
#
#             85plus    total_male  total_female
# count  3221.000000  3.221000e+03  3.221000e+03
# mean      2.249829  9.921802e+04  1.023321e+05
# std       0.921859  2.804990e+06  2.892100e+06
# min       0.000000  3.800000e+01  3.700000e+01
# 25%       1.600000  5.660000e+03  5.575000e+03
# 50%       2.100000  1.291800e+04  1.299700e+04
# 75%       2.700000  3.330100e+04  3.369200e+04
# max       8.500000  1.589842e+08  1.639188e+08

# %%
data2['percent_female'] = 100*data2['total_female']/data2['population']
data2['percent_male'] = 100*data2['total_male']/data2['population']
one = np.ones(len(data2['percent_female']))*100

data2['ageunder15'] = one -  data2[datacol[1:16]].sum(axis=1)
data2['age35_44']  = data2[datacol[5:7]].sum(axis=1)
data2['age45_54'] = data2[datacol[7:9]].sum(axis=1)
data2['age65_74'] = data2[datacol[11:13]].sum(axis=1)
data2['age_75over'] = data2[datacol[13:16]].sum(axis=1)

# %%
data = data2.drop(['35_39','40_44','45_49','50_54','65_69','70_74','75_79','80_84','85plus'],axis=1)

# %%
data['percent_totalpop'] = 100*data['population']/322903030.0

# %%
data
# Out:
#                                county   population  age15_19  age20_24  \
# 1             Autauga County, Alabama      55200.0       7.0       6.0
# 2             Baldwin County, Alabama     208107.0       6.1       5.2
# 3             Barbour County, Alabama      25782.0       5.6       6.4
# 4                Bibb County, Alabama      22527.0       6.7       6.6
# 5              Blount County, Alabama      57645.0       6.4       5.5
# ...                               ...          ...       ...       ...
# 3217   Vieques Municipio, Puerto Rico       8771.0       3.9       6.2
# 3218  Villalba Municipio, Puerto Rico      22993.0       8.1       7.7
# 3219   Yabucoa Municipio, Puerto Rico      34149.0       6.8       6.9
# 3220     Yauco Municipio, Puerto Rico      36439.0       6.5       6.3
# 3221                    United States  322903030.0       6.6       6.9
#
#       age25_29  age30_34  age55_59  age60_64   total_male  total_female  \
# 1          6.6       6.2       7.5       4.9      26874.0       28326.0
# 2          5.7       5.5       6.9       7.1     101188.0      106919.0
# 3          7.2       7.0       6.4       6.4      13697.0       12085.0
# 4          6.9       6.7       6.6       5.4      12152.0       10375.0
# 5          5.9       5.9       6.8       6.3      28434.0       29211.0
# ...        ...       ...       ...       ...          ...           ...
# 3217       6.0       5.7       7.3       7.5       4332.0        4439.0
# 3218       6.6       5.5       8.0       5.8      11169.0       11824.0
# 3219       6.2       5.3       6.6       7.5      16541.0       17608.0
# 3220       5.9       5.4       7.8       6.2      17475.0       18964.0
# 3221       7.1       6.7       6.7       6.1  158984190.0   163918840.0
#
#               geo_id  percent_female  percent_male  ageunder15  age35_44  \
# 1     0500000US01001       51.315217     48.684783        19.7      13.3
# 2     0500000US01003       51.376936     48.623064        18.2      12.2
# 3     0500000US01005       46.873788     53.126212        17.6      12.0
# 4     0500000US01007       46.055844     53.944156        16.7      12.9
# 5     0500000US01009       50.673953     49.326047        19.2      12.4
# ...              ...             ...           ...         ...       ...
# 3217  0500000US72147       50.609965     49.390035        18.4      12.0
# 3218  0500000US72149       51.424347     48.575653        17.8      11.5
# 3219  0500000US72151       51.562271     48.437729        16.2      12.3
# 3220  0500000US72153       52.043141     47.956859        16.0      12.2
# 3221       0100000US       50.764107     49.235893        18.9      12.6
#
#       age45_54  age65_74  age_75over  percent_totalpop
# 1         14.2       8.5         6.1          0.017095
# 2         13.6      11.8         7.7          0.064449
# 3         13.4      11.0         7.0          0.007984
# 4         15.2       9.4         6.9          0.006976
# 5         13.8      10.7         7.1          0.017852
# ...        ...       ...         ...               ...
# 3217      12.3      11.8         8.9          0.002716
# 3218      13.2       9.8         6.0          0.007121
# 3219      13.6      11.2         7.4          0.010576
# 3220      13.4      11.7         8.6          0.011285
# 3221      13.2       8.9         6.3        100.000000
#
# [3221 rows x 19 columns]

# %%
data.to_csv('pop_age_sex.csv')

# %%
datatem = pd.read_csv('pop_age_sex.csv')

# %%
datatem
# Out:
#       Unnamed: 0                           county   population  age15_19  \
# 0              1          Autauga County, Alabama      55200.0       7.0
# 1              2          Baldwin County, Alabama     208107.0       6.1
# 2              3          Barbour County, Alabama      25782.0       5.6
# 3              4             Bibb County, Alabama      22527.0       6.7
# 4              5           Blount County, Alabama      57645.0       6.4
# ...          ...                              ...          ...       ...
# 3216        3217   Vieques Municipio, Puerto Rico       8771.0       3.9
# 3217        3218  Villalba Municipio, Puerto Rico      22993.0       8.1
# 3218        3219   Yabucoa Municipio, Puerto Rico      34149.0       6.8
# 3219        3220     Yauco Municipio, Puerto Rico      36439.0       6.5
# 3220        3221                    United States  322903030.0       6.6
#
#       age20_24  age25_29  age30_34  age55_59  age60_64   total_male  \
# 0          6.0       6.6       6.2       7.5       4.9      26874.0
# 1          5.2       5.7       5.5       6.9       7.1     101188.0
# 2          6.4       7.2       7.0       6.4       6.4      13697.0
# 3          6.6       6.9       6.7       6.6       5.4      12152.0
# 4          5.5       5.9       5.9       6.8       6.3      28434.0
# ...        ...       ...       ...       ...       ...          ...
# 3216       6.2       6.0       5.7       7.3       7.5       4332.0
# 3217       7.7       6.6       5.5       8.0       5.8      11169.0
# 3218       6.9       6.2       5.3       6.6       7.5      16541.0
# 3219       6.3       5.9       5.4       7.8       6.2      17475.0
# 3220       6.9       7.1       6.7       6.7       6.1  158984190.0
#
#       total_female          geo_id  percent_female  percent_male  ageunder15  \
# 0          28326.0  0500000US01001       51.315217     48.684783        19.7
# 1         106919.0  0500000US01003       51.376936     48.623064        18.2
# 2          12085.0  0500000US01005       46.873788     53.126212        17.6
# 3          10375.0  0500000US01007       46.055844     53.944156        16.7
# 4          29211.0  0500000US01009       50.673953     49.326047        19.2
# ...            ...             ...             ...           ...         ...
# 3216        4439.0  0500000US72147       50.609965     49.390035        18.4
# 3217       11824.0  0500000US72149       51.424347     48.575653        17.8
# 3218       17608.0  0500000US72151       51.562271     48.437729        16.2
# 3219       18964.0  0500000US72153       52.043141     47.956859        16.0
# 3220   163918840.0       0100000US       50.764107     49.235893        18.9
#
#       age35_44  age45_54  age65_74  age_75over  percent_totalpop
# 0         13.3      14.2       8.5         6.1          0.017095
# 1         12.2      13.6      11.8         7.7          0.064449
# 2         12.0      13.4      11.0         7.0          0.007984
# 3         12.9      15.2       9.4         6.9          0.006976
# 4         12.4      13.8      10.7         7.1          0.017852
# ...        ...       ...       ...         ...               ...
# 3216      12.0      12.3      11.8         8.9          0.002716
# 3217      11.5      13.2       9.8         6.0          0.007121
# 3218      12.3      13.6      11.2         7.4          0.010576
# 3219      12.2      13.4      11.7         8.6          0.011285
# 3220      12.6      13.2       8.9         6.3        100.000000
#
# [3221 rows x 20 columns]

# %% [markdown]
# # PART 3: Income per capita

# %%
dt = pd.read_csv('income_percapita_org.csv')

# %%
dt = dt[1:]
dt
# Out:
#               GEO_ID                           NAME B19301_001E B19301_001M
# 3     0500000US28019    Choctaw County, Mississippi       20589        1079
# 4     0500000US28057   Itawamba County, Mississippi       20629        1120
# 5     0500000US28015    Carroll County, Mississippi       22567        2233
# 6     0500000US28043    Grenada County, Mississippi       21668        1565
# 7     0500000US28063  Jefferson County, Mississippi       13374        2461
# ...              ...                            ...         ...         ...
# 3217  0500000US19021       Buena Vista County, Iowa       26607        1466
# 3218  0500000US19077           Guthrie County, Iowa       28953        1108
# 3219  0500000US19091          Humboldt County, Iowa       29882        2355
# 3220  0500000US19183        Washington County, Iowa       29857        1424
# 3221       0100000US                  United States       32621          91
#
# [3219 rows x 4 columns]

# %%
dt['county'] = dt['NAME'].apply(lambda x: x.split(',')[0])

dt['state'] = dt['NAME'].apply(lambda x: x.split(',')[1] if len(x.split(','))>1 else x)
dt= dt.drop('B19301_001M',axis=1)

# %%
col_ = {'GEO_ID':'geo_id','B19301_001E':'income_percapita'}
dt = dt.rename(columns=col_)
dt = dt.drop('NAME',axis=1)

# %%
dt['income_percapita']= dt['income_percapita'].astype(float)

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3219 entries, 3 to 3221
# Data columns (total 4 columns):
# geo_id              3219 non-null object
# income_percapita    3218 non-null float64
# county              3219 non-null object
# state               3219 non-null object
# dtypes: float64(1), object(3)
# memory usage: 100.7+ KB

# %%
dt.to_csv('income_percapita.csv')

# %% [markdown]
# # PART 4: Land area

# %%
land = pd.read_csv('land.csv')
land
# Out:
#       Unnamed: 0      County States  LAND AREA(SQMI)
# 0              0     Autauga     AL           598.73
# 1              1     Baldwin     AL          1737.68
# 2              2     Barbour     AL           891.30
# 3              3        Bibb     AL           624.10
# 4              4      Blount     AL           646.77
# ...          ...         ...    ...              ...
# 3140        3140  Sweetwater     WY         10435.46
# 3141        3141       Teton     WY          4077.70
# 3142        3142       Uinta     WY          2084.15
# 3143        3143    Washakie     WY          2241.18
# 3144        3144      Weston     WY          2399.33
#
# [3145 rows x 4 columns]

# %% [markdown]
# # PART 5 - Merge all Census data

# %%
d1 = pd.read_csv('pop_age_sex.csv',index_col= 0)
d2 = pd.read_csv('income_percapita.csv',index_col= 0)
d3 = pd.read_csv('EMPLOYMENT_STATUS.csv',index_col= 0)
d4 = pd.read_csv('GINI_INDEX.csv',index_col= 0)
d5 = pd.read_csv('commute.csv',index_col= 0)
d6 = pd.read_csv('private_hc.csv',index_col= 0)
d7 = pd.read_csv('public_hc.csv',index_col= 0)
#d8 = pd.read_csv('WORKING_STATUS.csv',index_col= 0)
d9 = pd.read_csv('JHU_byCounty_confirmed_covid_0412.csv',index_col= 0)

# %%
d1 = d1.drop('county',axis=1)
d1
# Out:
#        population  age15_19  age20_24  age25_29  age30_34  age55_59  age60_64  \
# 1         55200.0       7.0       6.0       6.6       6.2       7.5       4.9
# 2        208107.0       6.1       5.2       5.7       5.5       6.9       7.1
# 3         25782.0       5.6       6.4       7.2       7.0       6.4       6.4
# 4         22527.0       6.7       6.6       6.9       6.7       6.6       5.4
# 5         57645.0       6.4       5.5       5.9       5.9       6.8       6.3
# ...           ...       ...       ...       ...       ...       ...       ...
# 3217       8771.0       3.9       6.2       6.0       5.7       7.3       7.5
# 3218      22993.0       8.1       7.7       6.6       5.5       8.0       5.8
# 3219      34149.0       6.8       6.9       6.2       5.3       6.6       7.5
# 3220      36439.0       6.5       6.3       5.9       5.4       7.8       6.2
# 3221  322903030.0       6.6       6.9       7.1       6.7       6.7       6.1
#
#        total_male  total_female          geo_id  percent_female  percent_male  \
# 1         26874.0       28326.0  0500000US01001       51.315217     48.684783
# 2        101188.0      106919.0  0500000US01003       51.376936     48.623064
# 3         13697.0       12085.0  0500000US01005       46.873788     53.126212
# 4         12152.0       10375.0  0500000US01007       46.055844     53.944156
# 5         28434.0       29211.0  0500000US01009       50.673953     49.326047
# ...           ...           ...             ...             ...           ...
# 3217       4332.0        4439.0  0500000US72147       50.609965     49.390035
# 3218      11169.0       11824.0  0500000US72149       51.424347     48.575653
# 3219      16541.0       17608.0  0500000US72151       51.562271     48.437729
# 3220      17475.0       18964.0  0500000US72153       52.043141     47.956859
# 3221  158984190.0   163918840.0       0100000US       50.764107     49.235893
#
#       ageunder15  age35_44  age45_54  age65_74  age_75over  percent_totalpop
# 1           19.7      13.3      14.2       8.5         6.1          0.017095
# 2           18.2      12.2      13.6      11.8         7.7          0.064449
# 3           17.6      12.0      13.4      11.0         7.0          0.007984
# 4           16.7      12.9      15.2       9.4         6.9          0.006976
# 5           19.2      12.4      13.8      10.7         7.1          0.017852
# ...          ...       ...       ...       ...         ...               ...
# 3217        18.4      12.0      12.3      11.8         8.9          0.002716
# 3218        17.8      11.5      13.2       9.8         6.0          0.007121
# 3219        16.2      12.3      13.6      11.2         7.4          0.010576
# 3220        16.0      12.2      13.4      11.7         8.6          0.011285
# 3221        18.9      12.6      13.2       8.9         6.3        100.000000
#
# [3221 rows x 18 columns]

# %%
d2
# Out:
#               geo_id  income_percapita              county          state
# 3     0500000US28019           20589.0      Choctaw County    Mississippi
# 4     0500000US28057           20629.0     Itawamba County    Mississippi
# 5     0500000US28015           22567.0      Carroll County    Mississippi
# 6     0500000US28043           21668.0      Grenada County    Mississippi
# 7     0500000US28063           13374.0    Jefferson County    Mississippi
# ...              ...               ...                 ...            ...
# 3217  0500000US19021           26607.0  Buena Vista County           Iowa
# 3218  0500000US19077           28953.0      Guthrie County           Iowa
# 3219  0500000US19091           29882.0     Humboldt County           Iowa
# 3220  0500000US19183           29857.0   Washington County           Iowa
# 3221       0100000US           32621.0       United States  United States
#
# [3219 rows x 4 columns]

# %%
data = d1.merge(d2[['geo_id','county','state','income_percapita']],how='left',on='geo_id')
data
# Out:
#        population  age15_19  age20_24  age25_29  age30_34  age55_59  age60_64  \
# 0         55200.0       7.0       6.0       6.6       6.2       7.5       4.9
# 1        208107.0       6.1       5.2       5.7       5.5       6.9       7.1
# 2         25782.0       5.6       6.4       7.2       7.0       6.4       6.4
# 3         22527.0       6.7       6.6       6.9       6.7       6.6       5.4
# 4         57645.0       6.4       5.5       5.9       5.9       6.8       6.3
# ...           ...       ...       ...       ...       ...       ...       ...
# 3216       8771.0       3.9       6.2       6.0       5.7       7.3       7.5
# 3217      22993.0       8.1       7.7       6.6       5.5       8.0       5.8
# 3218      34149.0       6.8       6.9       6.2       5.3       6.6       7.5
# 3219      36439.0       6.5       6.3       5.9       5.4       7.8       6.2
# 3220  322903030.0       6.6       6.9       7.1       6.7       6.7       6.1
#
#        total_male  total_female          geo_id  ...  percent_male  \
# 0         26874.0       28326.0  0500000US01001  ...     48.684783
# 1        101188.0      106919.0  0500000US01003  ...     48.623064
# 2         13697.0       12085.0  0500000US01005  ...     53.126212
# 3         12152.0       10375.0  0500000US01007  ...     53.944156
# 4         28434.0       29211.0  0500000US01009  ...     49.326047
# ...           ...           ...             ...  ...           ...
# 3216       4332.0        4439.0  0500000US72147  ...     49.390035
# 3217      11169.0       11824.0  0500000US72149  ...     48.575653
# 3218      16541.0       17608.0  0500000US72151  ...     48.437729
# 3219      17475.0       18964.0  0500000US72153  ...     47.956859
# 3220  158984190.0   163918840.0       0100000US  ...     49.235893
#
#       ageunder15  age35_44  age45_54  age65_74  age_75over  percent_totalpop  \
# 0           19.7      13.3      14.2       8.5         6.1          0.017095
# 1           18.2      12.2      13.6      11.8         7.7          0.064449
# 2           17.6      12.0      13.4      11.0         7.0          0.007984
# 3           16.7      12.9      15.2       9.4         6.9          0.006976
# 4           19.2      12.4      13.8      10.7         7.1          0.017852
# ...          ...       ...       ...       ...         ...               ...
# 3216        18.4      12.0      12.3      11.8         8.9          0.002716
# 3217        17.8      11.5      13.2       9.8         6.0          0.007121
# 3218        16.2      12.3      13.6      11.2         7.4          0.010576
# 3219        16.0      12.2      13.4      11.7         8.6          0.011285
# 3220        18.9      12.6      13.2       8.9         6.3        100.000000
#
#                   county          state income_percapita
# 0         Autauga County        Alabama          29372.0
# 1         Baldwin County        Alabama          31203.0
# 2         Barbour County        Alabama          18461.0
# 3            Bibb County        Alabama          20199.0
# 4          Blount County        Alabama          22656.0
# ...                  ...            ...              ...
# 3216   Vieques Municipio    Puerto Rico          11156.0
# 3217  Villalba Municipio    Puerto Rico          10677.0
# 3218   Yabucoa Municipio    Puerto Rico           9148.0
# 3219     Yauco Municipio    Puerto Rico           8339.0
# 3220       United States  United States          32621.0
#
# [3221 rows x 21 columns]

# %%
cols = data.columns.to_list()
col = {i:i.upper() for i in cols}
col
data = data.rename(columns=col)
data
# Out:
#        POPULATION  AGE15_19  AGE20_24  AGE25_29  AGE30_34  AGE55_59  AGE60_64  \
# 0         55200.0       7.0       6.0       6.6       6.2       7.5       4.9
# 1        208107.0       6.1       5.2       5.7       5.5       6.9       7.1
# 2         25782.0       5.6       6.4       7.2       7.0       6.4       6.4
# 3         22527.0       6.7       6.6       6.9       6.7       6.6       5.4
# 4         57645.0       6.4       5.5       5.9       5.9       6.8       6.3
# ...           ...       ...       ...       ...       ...       ...       ...
# 3216       8771.0       3.9       6.2       6.0       5.7       7.3       7.5
# 3217      22993.0       8.1       7.7       6.6       5.5       8.0       5.8
# 3218      34149.0       6.8       6.9       6.2       5.3       6.6       7.5
# 3219      36439.0       6.5       6.3       5.9       5.4       7.8       6.2
# 3220  322903030.0       6.6       6.9       7.1       6.7       6.7       6.1
#
#        TOTAL_MALE  TOTAL_FEMALE          GEO_ID  ...  PERCENT_MALE  \
# 0         26874.0       28326.0  0500000US01001  ...     48.684783
# 1        101188.0      106919.0  0500000US01003  ...     48.623064
# 2         13697.0       12085.0  0500000US01005  ...     53.126212
# 3         12152.0       10375.0  0500000US01007  ...     53.944156
# 4         28434.0       29211.0  0500000US01009  ...     49.326047
# ...           ...           ...             ...  ...           ...
# 3216       4332.0        4439.0  0500000US72147  ...     49.390035
# 3217      11169.0       11824.0  0500000US72149  ...     48.575653
# 3218      16541.0       17608.0  0500000US72151  ...     48.437729
# 3219      17475.0       18964.0  0500000US72153  ...     47.956859
# 3220  158984190.0   163918840.0       0100000US  ...     49.235893
#
#       AGEUNDER15  AGE35_44  AGE45_54  AGE65_74  AGE_75OVER  PERCENT_TOTALPOP  \
# 0           19.7      13.3      14.2       8.5         6.1          0.017095
# 1           18.2      12.2      13.6      11.8         7.7          0.064449
# 2           17.6      12.0      13.4      11.0         7.0          0.007984
# 3           16.7      12.9      15.2       9.4         6.9          0.006976
# 4           19.2      12.4      13.8      10.7         7.1          0.017852
# ...          ...       ...       ...       ...         ...               ...
# 3216        18.4      12.0      12.3      11.8         8.9          0.002716
# 3217        17.8      11.5      13.2       9.8         6.0          0.007121
# 3218        16.2      12.3      13.6      11.2         7.4          0.010576
# 3219        16.0      12.2      13.4      11.7         8.6          0.011285
# 3220        18.9      12.6      13.2       8.9         6.3        100.000000
#
#                   COUNTY          STATE INCOME_PERCAPITA
# 0         Autauga County        Alabama          29372.0
# 1         Baldwin County        Alabama          31203.0
# 2         Barbour County        Alabama          18461.0
# 3            Bibb County        Alabama          20199.0
# 4          Blount County        Alabama          22656.0
# ...                  ...            ...              ...
# 3216   Vieques Municipio    Puerto Rico          11156.0
# 3217  Villalba Municipio    Puerto Rico          10677.0
# 3218   Yabucoa Municipio    Puerto Rico           9148.0
# 3219     Yauco Municipio    Puerto Rico           8339.0
# 3220       United States  United States          32621.0
#
# [3221 rows x 21 columns]

# %%
d3.head()
# Out:
#                    STATE          COUNTY  LABOR_FORCE_PARTICIPATION_RATE  \
# GEO_ID
# 0500000US01001   Alabama  Autauga County                            59.3
# 0500000US01003   Alabama  Baldwin County                            58.5
# 0500000US01005   Alabama  Barbour County                            46.0
# 0500000US01007   Alabama     Bibb County                            47.4
# 0500000US01009   Alabama   Blount County                            48.6
#
#                LAB_16-19 LAB_20-24  LAB_25-29  LAB_30-34  LAB_35-44 LAB_45-54  \
# GEO_ID
# 0500000US01001      31.9      70.8       83.0       81.9       78.9      74.9
# 0500000US01003      39.1      77.1       81.3       78.8       81.3      80.5
# 0500000US01005      22.4      57.2       72.0       48.3       54.4      59.7
# 0500000US01007      16.9      58.4       56.6       58.1       64.5      61.1
# 0500000US01009      18.5      58.7       81.2       59.0       71.9      63.9
#
#                 LAB_55-59  ...  UNEMP_16-19  UNEMP_20-24  UNEMP_25-29  \
# GEO_ID                     ...
# 0500000US01001       66.2  ...         14.2         12.7          3.6
# 0500000US01003       69.3  ...         13.5          9.7          8.6
# 0500000US01005       51.7  ...         27.2         11.9         20.3
# 0500000US01007       56.2  ...         30.0         19.1          8.8
# 0500000US01009       63.0  ...         21.5          8.6          2.9
#
#                 UNEMP_30-34 UNEMP_35-44 UNEMP_45-54  UNEMP_55-59  UNEMP_60-64  \
# GEO_ID
# 0500000US01001          3.7         3.6         2.4          1.4          3.2
# 0500000US01003          2.2         2.4         4.4          1.4          2.0
# 0500000US01005         14.1         9.4         5.4          3.4          1.2
# 0500000US01007         16.8         5.0         3.7          0.6          1.9
# 0500000US01009          2.3         4.2         3.1          2.5          3.0
#
#                 UNEMP_65-74 UNEMP_OVER75
# GEO_ID
# 0500000US01001          1.5          0.0
# 0500000US01003          3.2          2.6
# 0500000US01005          3.0          9.2
# 0500000US01007          4.5          0.0
# 0500000US01009          2.4          0.0
#
# [5 rows x 35 columns]

# %%
d8.head()
# Out:
#                    STATE          COUNTY  WORK50-52  WORK1-49  WORK0
# GEO_ID
# 0500000US01003   Alabama  Baldwin County       57.4      17.7   24.9
# 0500000US01005   Alabama  Barbour County       42.4      14.3   43.3
# 0500000US01007   Alabama     Bibb County       45.9      11.8   42.3
# 0500000US01009   Alabama   Blount County       50.8      10.3   38.9
# 0500000US01011   Alabama  Bullock County       46.2      16.9   36.9

# %%
d4.head()
# Out:
#                        STATE             COUNTY  GINI_INDEX
# GEO_ID
# 0500000US28151   Mississippi  Washington County      0.5328
# 0500000US28111   Mississippi       Perry County      0.4818
# 0500000US28019   Mississippi     Choctaw County      0.4432
# 0500000US28057   Mississippi    Itawamba County      0.4299
# 0500000US28015   Mississippi     Carroll County      0.4489

# %%
def clean_data(d5):
    cols5 = d5.columns.to_list()
    cols5.remove('County')
    cols5.remove('States')
    col5 = {i:i.upper() for i in cols5}
    d5 = d5[cols5]
    d5 = d5.rename(columns=col5)
    d5 = d5.rename(columns={'ID': 'GEO_ID'})
    return d5

# %%
d5 = clean_data(d5)
d5
# Out:
#               GEO_ID  WORKERS 16 YEARS AND OVER  CAR, TRUCK, OR VAN  \
# 0     0500000US01001                    24428.0                95.2
# 1     0500000US01003                    91420.0                91.7
# 2     0500000US01005                     8538.0                94.2
# 3     0500000US01007                     7946.0                95.5
# 4     0500000US01009                    21148.0                96.6
# ...              ...                        ...                 ...
# 3215  0500000US72145                    14194.0                95.6
# 3216  0500000US72147                     2487.0                91.4
# 3217  0500000US72149                     6357.0                95.7
# 3218  0500000US72151                     7513.0                97.0
# 3219  0500000US72153                     8706.0                91.7
#
#      WORKERS PER CAR, TRUCK, OR VAN  \
# 0                              1.05
# 1                              1.05
# 2                              1.07
# 3                              1.06
# 4                              1.06
# ...                             ...
# 3215                           1.02
# 3216                           1.08
# 3217                           1.07
# 3218                           1.05
# 3219                           1.05
#
#       PUBLIC TRANSPORTATION (EXCLUDING TAXICAB)  WALKED  BICYCLE  \
# 0                                           0.1     0.6      0.1
# 1                                           0.1     0.7      0.1
# 2                                           0.3     2.1      0.0
# 3                                           0.5     0.6      0.0
# 4                                           0.1     0.2      0.0
# ...                                         ...     ...      ...
# 3215                                        0.7     1.4      0.2
# 3216                                        0.0     4.8      0.0
# 3217                                        0.1     2.3      0.0
# 3218                                        0.0     1.7      0.6
# 3219                                        1.7     1.6      0.0
#
#       TAXICAB, MOTORCYCLE, OR OTHER MEANS  WORKED AT HOME  \
# 0                                     1.3             2.8
# 1                                     1.3             6.1
# 2                                     2.1             1.3
# 3                                     0.9             2.6
# 4                                     0.8             2.3
# ...                                   ...             ...
# 3215                                  0.6             1.5
# 3216                                  0.0             3.8
# 3217                                  0.0             1.9
# 3218                                  0.6             0.1
# 3219                                  0.3             4.7
#
#       WORKED OUTSIDE COUNTY OF RESIDENCE  ...  LESS THAN 10 MINUTES  \
# 0                                   64.5  ...                  12.8
# 1                                   20.6  ...                  10.6
# 2                                   20.9  ...                  25.4
# 3                                   64.3  ...                  10.4
# 4                                   67.0  ...                  11.9
# ...                                  ...  ...                   ...
# 3215                                57.5  ...                   4.9
# 3216                                 1.6  ...                   8.7
# 3217                                53.9  ...                  16.9
# 3218                                66.9  ...                  10.9
# 3219                                43.7  ...                   8.3
#
#       10 TO 14 MINUTES  15 TO 19 MINUTES  20 TO 24 MINUTES  25 TO 29 MINUTES  \
# 0                 10.5              14.2              13.8               9.5
# 1                 13.2              14.1              13.4               6.6
# 2                 16.0              12.6              10.9               4.7
# 3                 14.1              10.3               8.5               5.0
# 4                  7.7               6.7               8.7               4.5
# ...                ...               ...               ...               ...
# 3215              10.9              13.8              17.5               8.4
# 3216              48.3              32.3               7.1               0.8
# 3217              11.6              12.5               6.4               4.4
# 3218               8.5              13.1              13.7               6.8
# 3219              28.5              14.9               8.6               3.4
#
#       30 TO 34 MINUTES  35 TO 44 MINUTES  45 TO 59 MINUTES  \
# 0                 20.0               7.4               6.0
# 1                 17.3               7.0               9.9
# 2                 10.8               3.4               8.1
# 3                 12.1              14.5              16.2
# 4                 12.5               8.6              21.4
# ...                ...               ...               ...
# 3215              14.1              11.6               6.0
# 3216               1.0               0.0               0.0
# 3217              13.2              10.4              10.3
# 3218              17.4               6.2               9.4
# 3219              22.0               3.6               5.7
#
#       60 OR MORE MINUTES  MEAN TRAVEL TIME TO WORK (MINUTES)
# 0                    5.7                                25.8
# 1                    7.9                                27.4
# 2                    8.0                                22.7
# 3                    8.9                                29.2
# 4                   18.0                                35.1
# ...                  ...                                 ...
# 3215                12.7                                29.7
# 3216                 1.6                                14.3
# 3217                14.4                                28.9
# 3218                13.9                                30.5
# 3219                 4.9                                23.2
#
# [3220 rows x 22 columns]

# %%
data = data.merge(d5,how='left',on='GEO_ID')

# %%
d6
# Out:
#                   id               County        States  \
# 0     0500000US01001       Autauga County       Alabama
# 1     0500000US01003       Baldwin County       Alabama
# 2     0500000US01005       Barbour County       Alabama
# 3     0500000US01007          Bibb County       Alabama
# 4     0500000US01009        Blount County       Alabama
# ...              ...                  ...           ...
# 1903  0500000US72143  Vega Alta Municipio   Puerto Rico
# 1904  0500000US72145  Vega Baja Municipio   Puerto Rico
# 1905  0500000US72149   Villalba Municipio   Puerto Rico
# 1906  0500000US72151    Yabucoa Municipio   Puerto Rico
# 1907  0500000US72153      Yauco Municipio   Puerto Rico
#
#       With private health insurance  No private health insurance
# 0                             35411                        18851
# 1                            150836                        59388
# 2                             10505                        11823
# 3                             12489                         7996
# 4                             38425                        19032
# ...                             ...                          ...
# 1903                           8872                        28193
# 1904                          18446                        33772
# 1905                           4763                        17652
# 1906                           8578                        25476
# 1907                           9637                        25889
#
# [1908 rows x 5 columns]

# %%
d6 = clean_data(d6)
d6.head()
# Out:
#            GEO_ID  WITH PRIVATE HEALTH INSURANCE  NO PRIVATE HEALTH INSURANCE
# 0  0500000US01001                          35411                        18851
# 1  0500000US01003                         150836                        59388
# 2  0500000US01005                          10505                        11823
# 3  0500000US01007                          12489                         7996
# 4  0500000US01009                          38425                        19032

# %%
data = data.merge(d6,how='left',on='GEO_ID')
data
# Out:
#        POPULATION  AGE15_19  AGE20_24  AGE25_29  AGE30_34  AGE55_59  AGE60_64  \
# 0         55200.0       7.0       6.0       6.6       6.2       7.5       4.9
# 1        208107.0       6.1       5.2       5.7       5.5       6.9       7.1
# 2         25782.0       5.6       6.4       7.2       7.0       6.4       6.4
# 3         22527.0       6.7       6.6       6.9       6.7       6.6       5.4
# 4         57645.0       6.4       5.5       5.9       5.9       6.8       6.3
# ...           ...       ...       ...       ...       ...       ...       ...
# 3216       8771.0       3.9       6.2       6.0       5.7       7.3       7.5
# 3217      22993.0       8.1       7.7       6.6       5.5       8.0       5.8
# 3218      34149.0       6.8       6.9       6.2       5.3       6.6       7.5
# 3219      36439.0       6.5       6.3       5.9       5.4       7.8       6.2
# 3220  322903030.0       6.6       6.9       7.1       6.7       6.7       6.1
#
#        TOTAL_MALE  TOTAL_FEMALE          GEO_ID  ...  15 TO 19 MINUTES  \
# 0         26874.0       28326.0  0500000US01001  ...              14.2
# 1        101188.0      106919.0  0500000US01003  ...              14.1
# 2         13697.0       12085.0  0500000US01005  ...              12.6
# 3         12152.0       10375.0  0500000US01007  ...              10.3
# 4         28434.0       29211.0  0500000US01009  ...               6.7
# ...           ...           ...             ...  ...               ...
# 3216       4332.0        4439.0  0500000US72147  ...              32.3
# 3217      11169.0       11824.0  0500000US72149  ...              12.5
# 3218      16541.0       17608.0  0500000US72151  ...              13.1
# 3219      17475.0       18964.0  0500000US72153  ...              14.9
# 3220  158984190.0   163918840.0       0100000US  ...               NaN
#
#       20 TO 24 MINUTES  25 TO 29 MINUTES  30 TO 34 MINUTES  35 TO 44 MINUTES  \
# 0                 13.8               9.5              20.0               7.4
# 1                 13.4               6.6              17.3               7.0
# 2                 10.9               4.7              10.8               3.4
# 3                  8.5               5.0              12.1              14.5
# 4                  8.7               4.5              12.5               8.6
# ...                ...               ...               ...               ...
# 3216               7.1               0.8               1.0               0.0
# 3217               6.4               4.4              13.2              10.4
# 3218              13.7               6.8              17.4               6.2
# 3219               8.6               3.4              22.0               3.6
# 3220               NaN               NaN               NaN               NaN
#
#       45 TO 59 MINUTES  60 OR MORE MINUTES  \
# 0                  6.0                 5.7
# 1                  9.9                 7.9
# 2                  8.1                 8.0
# 3                 16.2                 8.9
# 4                 21.4                18.0
# ...                ...                 ...
# 3216               0.0                 1.6
# 3217              10.3                14.4
# 3218               9.4                13.9
# 3219               5.7                 4.9
# 3220               NaN                 NaN
#
#       MEAN TRAVEL TIME TO WORK (MINUTES) WITH PRIVATE HEALTH INSURANCE  \
# 0                                   25.8                       35411.0
# 1                                   27.4                      150836.0
# 2                                   22.7                       10505.0
# 3                                   29.2                       12489.0
# 4                                   35.1                       38425.0
# ...                                  ...                           ...
# 3216                                14.3                           NaN
# 3217                                28.9                        4763.0
# 3218                                30.5                        8578.0
# 3219                                23.2                        9637.0
# 3220                                 NaN                           NaN
#
#      NO PRIVATE HEALTH INSURANCE
# 0                        18851.0
# 1                        59388.0
# 2                        11823.0
# 3                         7996.0
# 4                        19032.0
# ...                          ...
# 3216                         NaN
# 3217                     17652.0
# 3218                     25476.0
# 3219                     25889.0
# 3220                         NaN
#
# [3221 rows x 44 columns]

# %%
d7 = clean_data(d7)
d7
# Out:
#               GEO_ID  WITH PUBLIC COVERAGE  NO PUBLIC COVERAGE
# 0     0500000US01001                 20828               33434
# 1     0500000US01003                 73899              136325
# 2     0500000US01005                 12677                9651
# 3     0500000US01007                  8974               11511
# 4     0500000US01009                 20930               36527
# ...              ...                   ...                 ...
# 1903  0500000US72143                 27442                9623
# 1904  0500000US72145                 31718               20500
# 1905  0500000US72149                 16964                5451
# 1906  0500000US72151                 25538                8516
# 1907  0500000US72153                 25727                9799
#
# [1908 rows x 3 columns]

# %%
data = data.merge(d7,how='left',on='GEO_ID')
data
# Out:
#        POPULATION  AGE15_19  AGE20_24  AGE25_29  AGE30_34  AGE55_59  AGE60_64  \
# 0         55200.0       7.0       6.0       6.6       6.2       7.5       4.9
# 1        208107.0       6.1       5.2       5.7       5.5       6.9       7.1
# 2         25782.0       5.6       6.4       7.2       7.0       6.4       6.4
# 3         22527.0       6.7       6.6       6.9       6.7       6.6       5.4
# 4         57645.0       6.4       5.5       5.9       5.9       6.8       6.3
# ...           ...       ...       ...       ...       ...       ...       ...
# 3216       8771.0       3.9       6.2       6.0       5.7       7.3       7.5
# 3217      22993.0       8.1       7.7       6.6       5.5       8.0       5.8
# 3218      34149.0       6.8       6.9       6.2       5.3       6.6       7.5
# 3219      36439.0       6.5       6.3       5.9       5.4       7.8       6.2
# 3220  322903030.0       6.6       6.9       7.1       6.7       6.7       6.1
#
#        TOTAL_MALE  TOTAL_FEMALE          GEO_ID  ...  25 TO 29 MINUTES  \
# 0         26874.0       28326.0  0500000US01001  ...               9.5
# 1        101188.0      106919.0  0500000US01003  ...               6.6
# 2         13697.0       12085.0  0500000US01005  ...               4.7
# 3         12152.0       10375.0  0500000US01007  ...               5.0
# 4         28434.0       29211.0  0500000US01009  ...               4.5
# ...           ...           ...             ...  ...               ...
# 3216       4332.0        4439.0  0500000US72147  ...               0.8
# 3217      11169.0       11824.0  0500000US72149  ...               4.4
# 3218      16541.0       17608.0  0500000US72151  ...               6.8
# 3219      17475.0       18964.0  0500000US72153  ...               3.4
# 3220  158984190.0   163918840.0       0100000US  ...               NaN
#
#       30 TO 34 MINUTES  35 TO 44 MINUTES  45 TO 59 MINUTES  \
# 0                 20.0               7.4               6.0
# 1                 17.3               7.0               9.9
# 2                 10.8               3.4               8.1
# 3                 12.1              14.5              16.2
# 4                 12.5               8.6              21.4
# ...                ...               ...               ...
# 3216               1.0               0.0               0.0
# 3217              13.2              10.4              10.3
# 3218              17.4               6.2               9.4
# 3219              22.0               3.6               5.7
# 3220               NaN               NaN               NaN
#
#       60 OR MORE MINUTES  MEAN TRAVEL TIME TO WORK (MINUTES)  \
# 0                    5.7                                25.8
# 1                    7.9                                27.4
# 2                    8.0                                22.7
# 3                    8.9                                29.2
# 4                   18.0                                35.1
# ...                  ...                                 ...
# 3216                 1.6                                14.3
# 3217                14.4                                28.9
# 3218                13.9                                30.5
# 3219                 4.9                                23.2
# 3220                 NaN                                 NaN
#
#       WITH PRIVATE HEALTH INSURANCE  NO PRIVATE HEALTH INSURANCE  \
# 0                           35411.0                      18851.0
# 1                          150836.0                      59388.0
# 2                           10505.0                      11823.0
# 3                           12489.0                       7996.0
# 4                           38425.0                      19032.0
# ...                             ...                          ...
# 3216                            NaN                          NaN
# 3217                         4763.0                      17652.0
# 3218                         8578.0                      25476.0
# 3219                         9637.0                      25889.0
# 3220                            NaN                          NaN
#
#      WITH PUBLIC COVERAGE NO PUBLIC COVERAGE
# 0                 20828.0            33434.0
# 1                 73899.0           136325.0
# 2                 12677.0             9651.0
# 3                  8974.0            11511.0
# 4                 20930.0            36527.0
# ...                   ...                ...
# 3216                  NaN                NaN
# 3217              16964.0             5451.0
# 3218              25538.0             8516.0
# 3219              25727.0             9799.0
# 3220                  NaN                NaN
#
# [3221 rows x 46 columns]

# %%
data
# Out:
#        POPULATION  AGE15_19  AGE20_24  AGE25_29  AGE30_34  AGE55_59  AGE60_64  \
# 0         55200.0       7.0       6.0       6.6       6.2       7.5       4.9
# 1        208107.0       6.1       5.2       5.7       5.5       6.9       7.1
# 2         25782.0       5.6       6.4       7.2       7.0       6.4       6.4
# 3         22527.0       6.7       6.6       6.9       6.7       6.6       5.4
# 4         57645.0       6.4       5.5       5.9       5.9       6.8       6.3
# ...           ...       ...       ...       ...       ...       ...       ...
# 3216       8771.0       3.9       6.2       6.0       5.7       7.3       7.5
# 3217      22993.0       8.1       7.7       6.6       5.5       8.0       5.8
# 3218      34149.0       6.8       6.9       6.2       5.3       6.6       7.5
# 3219      36439.0       6.5       6.3       5.9       5.4       7.8       6.2
# 3220  322903030.0       6.6       6.9       7.1       6.7       6.7       6.1
#
#        TOTAL_MALE  TOTAL_FEMALE          GEO_ID  ...  25 TO 29 MINUTES  \
# 0         26874.0       28326.0  0500000US01001  ...               9.5
# 1        101188.0      106919.0  0500000US01003  ...               6.6
# 2         13697.0       12085.0  0500000US01005  ...               4.7
# 3         12152.0       10375.0  0500000US01007  ...               5.0
# 4         28434.0       29211.0  0500000US01009  ...               4.5
# ...           ...           ...             ...  ...               ...
# 3216       4332.0        4439.0  0500000US72147  ...               0.8
# 3217      11169.0       11824.0  0500000US72149  ...               4.4
# 3218      16541.0       17608.0  0500000US72151  ...               6.8
# 3219      17475.0       18964.0  0500000US72153  ...               3.4
# 3220  158984190.0   163918840.0       0100000US  ...               NaN
#
#       30 TO 34 MINUTES  35 TO 44 MINUTES  45 TO 59 MINUTES  \
# 0                 20.0               7.4               6.0
# 1                 17.3               7.0               9.9
# 2                 10.8               3.4               8.1
# 3                 12.1              14.5              16.2
# 4                 12.5               8.6              21.4
# ...                ...               ...               ...
# 3216               1.0               0.0               0.0
# 3217              13.2              10.4              10.3
# 3218              17.4               6.2               9.4
# 3219              22.0               3.6               5.7
# 3220               NaN               NaN               NaN
#
#       60 OR MORE MINUTES  MEAN TRAVEL TIME TO WORK (MINUTES)  \
# 0                    5.7                                25.8
# 1                    7.9                                27.4
# 2                    8.0                                22.7
# 3                    8.9                                29.2
# 4                   18.0                                35.1
# ...                  ...                                 ...
# 3216                 1.6                                14.3
# 3217                14.4                                28.9
# 3218                13.9                                30.5
# 3219                 4.9                                23.2
# 3220                 NaN                                 NaN
#
#       WITH PRIVATE HEALTH INSURANCE  NO PRIVATE HEALTH INSURANCE  \
# 0                           35411.0                      18851.0
# 1                          150836.0                      59388.0
# 2                           10505.0                      11823.0
# 3                           12489.0                       7996.0
# 4                           38425.0                      19032.0
# ...                             ...                          ...
# 3216                            NaN                          NaN
# 3217                         4763.0                      17652.0
# 3218                         8578.0                      25476.0
# 3219                         9637.0                      25889.0
# 3220                            NaN                          NaN
#
#      WITH PUBLIC COVERAGE NO PUBLIC COVERAGE
# 0                 20828.0            33434.0
# 1                 73899.0           136325.0
# 2                 12677.0             9651.0
# 3                  8974.0            11511.0
# 4                 20930.0            36527.0
# ...                   ...                ...
# 3216                  NaN                NaN
# 3217              16964.0             5451.0
# 3218              25538.0             8516.0
# 3219              25727.0             9799.0
# 3220                  NaN                NaN
#
# [3221 rows x 46 columns]

# %%
data['GEO_ID']
# Out:
# 0       0500000US01001
# 1       0500000US01003
# 2       0500000US01005
# 3       0500000US01007
# 4       0500000US01009
#              ...
# 3216    0500000US72147
# 3217    0500000US72149
# 3218    0500000US72151
# 3219    0500000US72153
# 3220         0100000US
# Name: GEO_ID, Length: 3221, dtype: object

# %%
data.columns
# Out:
# Index(['POPULATION', 'AGE15_19', 'AGE20_24', 'AGE25_29', 'AGE30_34',
#        'AGE55_59', 'AGE60_64', 'TOTAL_MALE', 'TOTAL_FEMALE', 'GEO_ID',
#        'PERCENT_FEMALE', 'PERCENT_MALE', 'AGEUNDER15', 'AGE35_44', 'AGE45_54',
#        'AGE65_74', 'AGE_75OVER', 'PERCENT_TOTALPOP', 'COUNTY', 'STATE',
#        'INCOME_PERCAPITA', 'WORKERS 16 YEARS AND OVER', 'CAR, TRUCK, OR VAN',
#        'WORKERS PER CAR, TRUCK, OR VAN',
#        'PUBLIC TRANSPORTATION (EXCLUDING TAXICAB)', 'WALKED', 'BICYCLE',
#        'TAXICAB, MOTORCYCLE, OR OTHER MEANS', 'WORKED AT HOME',
#        'WORKED OUTSIDE COUNTY OF RESIDENCE',
#        'WORKED OUTSIDE STATE OF RESIDENCE',
#        'WORKERS 16 YEARS AND OVER WHO DID NOT WORK AT HOME',
#        'LESS THAN 10 MINUTES', '10 TO 14 MINUTES', '15 TO 19 MINUTES',
#        '20 TO 24 MINUTES', '25 TO 29 MINUTES', '30 TO 34 MINUTES',
#        '35 TO 44 MINUTES', '45 TO 59 MINUTES', '60 OR MORE MINUTES',
#        'MEAN TRAVEL TIME TO WORK (MINUTES)', 'WITH PRIVATE HEALTH INSURANCE',
#        'NO PRIVATE HEALTH INSURANCE', 'WITH PUBLIC COVERAGE',
#        'NO PUBLIC COVERAGE'],
#       dtype='object')

# %%
data['COUNTY']
# Out:
# 0           Autauga County
# 1           Baldwin County
# 2           Barbour County
# 3              Bibb County
# 4            Blount County
#                ...
# 3216     Vieques Municipio
# 3217    Villalba Municipio
# 3218     Yabucoa Municipio
# 3219       Yauco Municipio
# 3220         United States
# Name: COUNTY, Length: 3221, dtype: object

# %%
d9 = pd.read_csv('JHU_byCounty_confirmed_covid_0412.csv',index_col= 0)
d9 = d9.reset_index()
d9 = d9[d9['iso3'] == 'USA']
d9_filter = d9[(d9['Admin2'] != 'Unassigned')]
#d9_filter = d9[d9['Admin2'] == None]
d9_filter
# Out:
#            UID iso2 iso3  code3     FIPS     Admin2    Province_State  \
# 5     84001001   US  USA    840   1001.0    Autauga           Alabama
# 6     84001003   US  USA    840   1003.0    Baldwin           Alabama
# 7     84001005   US  USA    840   1005.0    Barbour           Alabama
# 8     84001007   US  USA    840   1007.0       Bibb           Alabama
# 9     84001009   US  USA    840   1009.0     Blount           Alabama
# ...        ...  ...  ...    ...      ...        ...               ...
# 3197  84080054   US  USA    840  80054.0  Out of WV     West Virginia
# 3198  84080055   US  USA    840  80055.0  Out of WI         Wisconsin
# 3199  84080056   US  USA    840  80056.0  Out of WY           Wyoming
# 3200  84088888   US  USA    840  88888.0        NaN  Diamond Princess
# 3252  84099999   US  USA    840  99999.0        NaN    Grand Princess
#
#      Country_Region        Lat      Long_  ... 4/3/20  4/4/20  4/5/20  4/6/20  \
# 5                US  32.539527 -86.644082  ...     12      12      12      12
# 6                US  30.727750 -87.722071  ...     28      29      29      38
# 7                US  31.868263 -85.387129  ...      1       2       2       2
# 8                US  32.996421 -87.125115  ...      4       4       5       7
# 9                US  33.982109 -86.567906  ...      9      10      10      10
# ...             ...        ...        ...  ...    ...     ...     ...     ...
# 3197             US   0.000000   0.000000  ...      0       0       0       0
# 3198             US   0.000000   0.000000  ...      0       0       0       0
# 3199             US   0.000000   0.000000  ...      0       0       0       0
# 3200             US   0.000000   0.000000  ...     49      49      49      49
# 3252             US   0.000000   0.000000  ...    103     103     103     103
#
#       4/7/20  4/8/20  4/9/20  4/10/20  4/11/20  4/12/20
# 5         12      12      15       17       19       19
# 6         42      44      56       59       66       71
# 7          3       3       4        9        9       10
# 8          8       9       9       11       13       16
# 9         10      10      11       12       12       13
# ...      ...     ...     ...      ...      ...      ...
# 3197       0       0       0        0        0        0
# 3198       0       0       0        0        0        0
# 3199       0       0       0        0        0        0
# 3200      49      49      49       49       49       49
# 3252     103     103     103      103      103      103
#
# [3197 rows x 93 columns]

# %%
d11 = pd.read_csv('processed_gm_data.csv')
d11.head()
# Out:
#                id     Geographic Area Name  Less than high school graduate  \
# 0  0500000US01001  Autauga County, Alabama                          4204.0
# 1  0500000US01003  Baldwin County, Alabama                         14310.0
# 2  0500000US01005  Barbour County, Alabama                          4901.0
# 3  0500000US01007     Bibb County, Alabama                          2650.0
# 4  0500000US01009   Blount County, Alabama                          7861.0
#
#    High school graduate (includes equivalency)  \
# 0                                      12119.0
# 1                                      40579.0
# 2                                       6486.0
# 3                                       7471.0
# 4                                      13489.0
#
#    Some college or associate's degree  Bachelor's degree  \
# 0                             10552.0             5903.0
# 1                             46025.0            30431.0
# 2                              4566.0             1417.0
# 3                              3846.0             1197.0
# 4                             13267.0             3217.0
#
#    Graduate or professional degree  $1 to $9,999 or loss  $10,000 to $14,999  \
# 0                           4388.0                6339.0              4126.0
# 1                          15644.0               24827.0             15759.0
# 2                            803.0                4808.0              2734.0
# 3                            616.0                2983.0              1886.0
# 4                           1793.0                6275.0              4113.0
#
#    $15,000 to $24,999  ...  $35,000 to $49,999  $50,000 to $64,999  \
# 0              6267.0  ...              5708.0              3744.0
# 1             25871.0  ...             21975.0             14480.0
# 2              3283.0  ...              1809.0              1089.0
# 3              3235.0  ...              1605.0              1047.0
# 4              6795.0  ...              5206.0              3861.0
#
#    $65,000 to $74,999  $75,000 or more  Median income (dollars)  \
# 0              1436.0           5779.0                    29667
# 1              5535.0          20333.0                    28632
# 2               343.0           1155.0                    18138
# 3               704.0           1046.0                    22298
# 4              1555.0           3082.0                    26509
#
#   Below 100 percent of the poverty level  \
# 0                                 8276.0
# 1                                21239.0
# 2                                 6332.0
# 3                                 2782.0
# 4                                 8084.0
#
#    100 to 149 percent of the poverty level  \
# 0                                   4579.0
# 1                                  16032.0
# 2                                   2690.0
# 3                                   2347.0
# 4                                   6249.0
#
#    At or above 150 percent of the poverty level  \
# 0                                       41219.0
# 1                                      165641.0
# 2                                       13521.0
# 3                                       14924.0
# 4                                       42291.0
#
#    Householder lived in owner-occupied housing units  \
# 0                                            40538.0
# 1                                           152375.0
# 2                                            13662.0
# 3                                            15370.0
# 4                                            45751.0
#
#    Householder lived in renter-occupied housing units
# 0                                            13425.0
# 1                                            50637.0
# 2                                             8907.0
# 3                                             4651.0
# 4                                            10850.0
#
# [5 rows x 21 columns]

# %%
def clean_data(d5):
    cols5 = d5.columns.to_list()
    #cols5.remove('County')
    #cols5.remove('States')
    col5 = {i:i.upper() for i in cols5}
    d5 = d5[cols5]
    d5 = d5.rename(columns=col5)
    d5 = d5.rename(columns={'ID': 'GEO_ID'})
    return d5
d11 = clean_data(d11)
d11.columns
# Out:
# Index(['GEO_ID', 'GEOGRAPHIC AREA NAME', 'LESS THAN HIGH SCHOOL GRADUATE',
#        'HIGH SCHOOL GRADUATE (INCLUDES EQUIVALENCY)',
#        'SOME COLLEGE OR ASSOCIATE'S DEGREE', 'BACHELOR'S DEGREE',
#        'GRADUATE OR PROFESSIONAL DEGREE', '$1 TO $9,999 OR LOSS',
#        '$10,000 TO $14,999', '$15,000 TO $24,999', '$25,000 TO $34,999',
#        '$35,000 TO $49,999', '$50,000 TO $64,999', '$65,000 TO $74,999',
#        '$75,000 OR MORE', 'MEDIAN INCOME (DOLLARS)',
#        'BELOW 100 PERCENT OF THE POVERTY LEVEL',
#        '100 TO 149 PERCENT OF THE POVERTY LEVEL',
#        'AT OR ABOVE 150 PERCENT OF THE POVERTY LEVEL',
#        'HOUSEHOLDER LIVED IN OWNER-OCCUPIED HOUSING UNITS',
#        'HOUSEHOLDER LIVED IN RENTER-OCCUPIED HOUSING UNITS'],
#       dtype='object')

# %%
#add percent_male, drop total_female, add area!!!, bin age again
#take a look: 'WORKERS 16 YEARS AND OVER' when we have unemployment rate
#impute missing: 
data.columns
# Out:
# Index(['POPULATION', 'AGE15_19', 'AGE20_24', 'AGE25_29', 'AGE30_34',
#        'AGE55_59', 'AGE60_64', 'TOTAL_MALE', 'TOTAL_FEMALE', 'GEO_ID',
#        'PERCENT_FEMALE', 'PERCENT_MALE', 'AGEUNDER15', 'AGE35_44', 'AGE45_54',
#        'AGE65_74', 'AGE_75OVER', 'PERCENT_TOTALPOP', 'COUNTY', 'STATE',
#        'INCOME_PERCAPITA', 'WORKERS 16 YEARS AND OVER', 'CAR, TRUCK, OR VAN',
#        'WORKERS PER CAR, TRUCK, OR VAN',
#        'PUBLIC TRANSPORTATION (EXCLUDING TAXICAB)', 'WALKED', 'BICYCLE',
#        'TAXICAB, MOTORCYCLE, OR OTHER MEANS', 'WORKED AT HOME',
#        'WORKED OUTSIDE COUNTY OF RESIDENCE',
#        'WORKED OUTSIDE STATE OF RESIDENCE',
#        'WORKERS 16 YEARS AND OVER WHO DID NOT WORK AT HOME',
#        'LESS THAN 10 MINUTES', '10 TO 14 MINUTES', '15 TO 19 MINUTES',
#        '20 TO 24 MINUTES', '25 TO 29 MINUTES', '30 TO 34 MINUTES',
#        '35 TO 44 MINUTES', '45 TO 59 MINUTES', '60 OR MORE MINUTES',
#        'MEAN TRAVEL TIME TO WORK (MINUTES)', 'WITH PRIVATE HEALTH INSURANCE',
#        'NO PRIVATE HEALTH INSURANCE', 'WITH PUBLIC COVERAGE',
#        'NO PUBLIC COVERAGE'],
#       dtype='object')

# %%
data = data.merge(d11,how='left',on='GEO_ID')

# %%
data[data['WITH PRIVATE HEALTH INSURANCE'].isna() == True]['STATE'].unique()
# Out:
# array([' Alabama', ' Alaska', ' Arizona', ' Arkansas', ' California',
#        ' Colorado', ' Florida', ' Georgia', ' Hawaii', ' Idaho',
#        ' Illinois', ' Indiana', ' Iowa', ' Kansas', ' Kentucky',
#        ' Louisiana', ' Maine', ' Maryland', ' Massachusetts', ' Michigan',
#        ' Minnesota', ' Mississippi', nan, ' Missouri', ' Montana',
#        ' Nebraska', ' Nevada', ' New Mexico', ' New York',
#        ' North Carolina', ' North Dakota', ' Ohio', ' Oklahoma',
#        ' Oregon', ' Pennsylvania', ' South Carolina', ' South Dakota',
#        ' Tennessee', ' Texas', ' Utah', ' Vermont', ' Virginia',
#        ' Washington', ' West Virginia', ' Wisconsin', ' Wyoming',
#        ' Puerto Rico', 'United States'], dtype=object)

# %%
#d3 = d3.drop('STATE',axis=1)
#d3 = d3.drop('COUNTY',axis=1)

#d3 = d3.reset_index()
#d3 = d3.drop('level_0',axis=1)
#d3 = d3.drop('index',axis=1)
d3
# Out:
#               GEO_ID  LABOR_FORCE_PARTICIPATION_RATE LAB_16-19 LAB_20-24  \
# 0     0500000US01001                            59.3      31.9      70.8
# 1     0500000US01003                            58.5      39.1      77.1
# 2     0500000US01005                            46.0      22.4      57.2
# 3     0500000US01007                            47.4      16.9      58.4
# 4     0500000US01009                            48.6      18.5      58.7
# ...              ...                             ...       ...       ...
# 3216  0500000US72147                            41.5      21.9      74.5
# 3217  0500000US72149                            46.1      17.8      61.4
# 3218  0500000US72151                            38.7      14.4      62.1
# 3219  0500000US72153                            36.9       6.5      34.8
# 3220       0100000US                            63.3      38.0      74.6
#
#       LAB_25-29  LAB_30-34  LAB_35-44 LAB_45-54  LAB_55-59  LAB_60-64  ...  \
# 0          83.0       81.9       78.9      74.9       66.2       52.1  ...
# 1          81.3       78.8       81.3      80.5       69.3       48.8  ...
# 2          72.0       48.3       54.4      59.7       51.7       44.6  ...
# 3          56.6       58.1       64.5      61.1       56.2       52.1  ...
# 4          81.2       59.0       71.9      63.9       63.0       39.3  ...
# ...         ...        ...        ...       ...        ...        ...  ...
# 3216       65.2       75.0       58.7      48.5       66.1       11.9  ...
# 3217       83.3       78.4       74.1      58.4       40.1       25.7  ...
# 3218       78.8       66.1       65.5      50.4       33.7       11.5  ...
# 3219       65.8       58.7       70.1      55.6       31.4       22.5  ...
# 3220       82.6       82.6       82.6      80.5       72.3       56.4  ...
#
#       UNEMP_16-19  UNEMP_20-24  UNEMP_25-29 UNEMP_30-34 UNEMP_35-44  \
# 0            14.2         12.7          3.6         3.7         3.6
# 1            13.5          9.7          8.6         2.2         2.4
# 2            27.2         11.9         20.3        14.1         9.4
# 3            30.0         19.1          8.8        16.8         5.0
# 4            21.5          8.6          2.9         2.3         4.2
# ...           ...          ...          ...         ...         ...
# 3216          0.0         11.6         21.1        11.1        25.9
# 3217         64.7         56.3         33.1        20.8        11.2
# 3218         70.1         40.0         19.7        25.1        31.1
# 3219         56.3         44.3         19.4        24.3        16.7
# 3220         18.9         10.5          6.8         5.5         4.6
#
#       UNEMP_45-54  UNEMP_55-59  UNEMP_60-64 UNEMP_65-74  UNEMP_OVER75
# 0             2.4          1.4          3.2         1.5           0.0
# 1             4.4          1.4          2.0         3.2           2.6
# 2             5.4          3.4          1.2         3.0           9.2
# 3             3.7          0.6          1.9         4.5           0.0
# 4             3.1          2.5          3.0         2.4           0.0
# ...           ...          ...          ...         ...           ...
# 3216          5.9         14.6         26.9         0.0             -
# 3217         11.4         13.9          4.4         0.0           0.0
# 3218         15.9         15.1         24.4         0.0           0.0
# 3219         17.6         20.4         11.7         0.0           0.0
# 3220          4.3          4.1          3.7         3.5           3.5
#
# [3221 rows x 34 columns]

# %%
data = data.merge(d3,how='left',on='GEO_ID')
data
# Out:
#        POPULATION  AGE15_19  AGE20_24  AGE25_29  AGE30_34  AGE55_59  AGE60_64  \
# 0         55200.0       7.0       6.0       6.6       6.2       7.5       4.9
# 1        208107.0       6.1       5.2       5.7       5.5       6.9       7.1
# 2         25782.0       5.6       6.4       7.2       7.0       6.4       6.4
# 3         22527.0       6.7       6.6       6.9       6.7       6.6       5.4
# 4         57645.0       6.4       5.5       5.9       5.9       6.8       6.3
# ...           ...       ...       ...       ...       ...       ...       ...
# 3216       8771.0       3.9       6.2       6.0       5.7       7.3       7.5
# 3217      22993.0       8.1       7.7       6.6       5.5       8.0       5.8
# 3218      34149.0       6.8       6.9       6.2       5.3       6.6       7.5
# 3219      36439.0       6.5       6.3       5.9       5.4       7.8       6.2
# 3220  322903030.0       6.6       6.9       7.1       6.7       6.7       6.1
#
#        TOTAL_MALE  TOTAL_FEMALE          GEO_ID  ...  UNEMP_16-19  \
# 0         26874.0       28326.0  0500000US01001  ...         14.2
# 1        101188.0      106919.0  0500000US01003  ...         13.5
# 2         13697.0       12085.0  0500000US01005  ...         27.2
# 3         12152.0       10375.0  0500000US01007  ...         30.0
# 4         28434.0       29211.0  0500000US01009  ...         21.5
# ...           ...           ...             ...  ...          ...
# 3216       4332.0        4439.0  0500000US72147  ...          0.0
# 3217      11169.0       11824.0  0500000US72149  ...         64.7
# 3218      16541.0       17608.0  0500000US72151  ...         70.1
# 3219      17475.0       18964.0  0500000US72153  ...         56.3
# 3220  158984190.0   163918840.0       0100000US  ...         18.9
#
#       UNEMP_20-24  UNEMP_25-29  UNEMP_30-34  UNEMP_35-44  UNEMP_45-54  \
# 0            12.7          3.6          3.7          3.6          2.4
# 1             9.7          8.6          2.2          2.4          4.4
# 2            11.9         20.3         14.1          9.4          5.4
# 3            19.1          8.8         16.8          5.0          3.7
# 4             8.6          2.9          2.3          4.2          3.1
# ...           ...          ...          ...          ...          ...
# 3216         11.6         21.1         11.1         25.9          5.9
# 3217         56.3         33.1         20.8         11.2         11.4
# 3218         40.0         19.7         25.1         31.1         15.9
# 3219         44.3         19.4         24.3         16.7         17.6
# 3220         10.5          6.8          5.5          4.6          4.3
#
#       UNEMP_55-59  UNEMP_60-64 UNEMP_65-74 UNEMP_OVER75
# 0             1.4          3.2         1.5          0.0
# 1             1.4          2.0         3.2          2.6
# 2             3.4          1.2         3.0          9.2
# 3             0.6          1.9         4.5          0.0
# 4             2.5          3.0         2.4          0.0
# ...           ...          ...         ...          ...
# 3216         14.6         26.9         0.0            -
# 3217         13.9          4.4         0.0          0.0
# 3218         15.1         24.4         0.0          0.0
# 3219         20.4         11.7         0.0          0.0
# 3220          4.1          3.7         3.5          3.5
#
# [3221 rows x 99 columns]

# %%
data['COUNTY'].tail(100)
# Out:
# 3121       Campbell County
# 3122         Carbon County
# 3123       Converse County
# 3124          Crook County
# 3125        Fremont County
#                ...
# 3216     Vieques Municipio
# 3217    Villalba Municipio
# 3218     Yabucoa Municipio
# 3219       Yauco Municipio
# 3220         United States
# Name: COUNTY, Length: 100, dtype: object

# %%
colwrong = ['WORKERS PER CAR, TRUCK, OR VAN','MEAN TRAVEL TIME TO WORK (MINUTES)','MEDIAN INCOME (DOLLARS)',
           'LAB_16-19','LAB_20-24','EMP_45-54','UNEMP_16-19','UNEMP_20-24','UNEMP_25-29','UNEMP_45-54','UNEMP_65-74',
            'UNEMP_OVER75']
#data[colwrong] = data[colwrong].astype(float) -> null value - cannot do

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3221 entries, 0 to 3220
# Data columns (total 99 columns):
# POPULATION                                            3221 non-null float64
# AGE15_19                                              3221 non-null float64
# AGE20_24                                              3221 non-null float64
# AGE25_29                                              3221 non-null float64
# AGE30_34                                              3221 non-null float64
# AGE55_59                                              3221 non-null float64
# AGE60_64                                              3221 non-null float64
# TOTAL_MALE                                            3221 non-null float64
# TOTAL_FEMALE                                          3221 non-null float64
# GEO_ID                                                3221 non-null object
# PERCENT_FEMALE                                        3221 non-null float64
# PERCENT_MALE                                          3221 non-null float64
# AGEUNDER15                                            3221 non-null float64
# AGE35_44                                              3221 non-null float64
# AGE45_54                                              3221 non-null float64
# AGE65_74                                              3221 non-null float64
# AGE_75OVER                                            3221 non-null float64
# PERCENT_TOTALPOP                                      3221 non-null float64
# COUNTY                                                3219 non-null object
# STATE                                                 3219 non-null object
# INCOME_PERCAPITA                                      3218 non-null float64
# WORKERS 16 YEARS AND OVER                             3219 non-null float64
# CAR, TRUCK, OR VAN                                    3219 non-null float64
# WORKERS PER CAR, TRUCK, OR VAN                        3219 non-null object
# PUBLIC TRANSPORTATION (EXCLUDING TAXICAB)             3219 non-null float64
# WALKED                                                3219 non-null float64
# BICYCLE                                               3219 non-null float64
# TAXICAB, MOTORCYCLE, OR OTHER MEANS                   3219 non-null float64
# WORKED AT HOME                                        3219 non-null float64
# WORKED OUTSIDE COUNTY OF RESIDENCE                    3219 non-null float64
# WORKED OUTSIDE STATE OF RESIDENCE                     3219 non-null float64
# WORKERS 16 YEARS AND OVER WHO DID NOT WORK AT HOME    3219 non-null float64
# LESS THAN 10 MINUTES                                  3219 non-null float64
# 10 TO 14 MINUTES                                      3219 non-null float64
# 15 TO 19 MINUTES                                      3219 non-null float64
# 20 TO 24 MINUTES                                      3219 non-null float64
# 25 TO 29 MINUTES                                      3219 non-null float64
# 30 TO 34 MINUTES                                      3219 non-null float64
# 35 TO 44 MINUTES                                      3219 non-null float64
# 45 TO 59 MINUTES                                      3219 non-null float64
# 60 OR MORE MINUTES                                    3219 non-null float64
# MEAN TRAVEL TIME TO WORK (MINUTES)                    3219 non-null object
# WITH PRIVATE HEALTH INSURANCE                         1908 non-null float64
# NO PRIVATE HEALTH INSURANCE                           1908 non-null float64
# WITH PUBLIC COVERAGE                                  1908 non-null float64
# NO PUBLIC COVERAGE                                    1908 non-null float64
# GEOGRAPHIC AREA NAME                                  3221 non-null object
# LESS THAN HIGH SCHOOL GRADUATE                        3142 non-null float64
# HIGH SCHOOL GRADUATE (INCLUDES EQUIVALENCY)           3142 non-null float64
# SOME COLLEGE OR ASSOCIATE'S DEGREE                    3142 non-null float64
# BACHELOR'S DEGREE                                     3142 non-null float64
# GRADUATE OR PROFESSIONAL DEGREE                       3142 non-null float64
# $1 TO $9,999 OR LOSS                                  3142 non-null float64
# $10,000 TO $14,999                                    3142 non-null float64
# $15,000 TO $24,999                                    3142 non-null float64
# $25,000 TO $34,999                                    3142 non-null float64
# $35,000 TO $49,999                                    3142 non-null float64
# $50,000 TO $64,999                                    3142 non-null float64
# $65,000 TO $74,999                                    3142 non-null float64
# $75,000 OR MORE                                       3142 non-null float64
# MEDIAN INCOME (DOLLARS)                               3142 non-null object
# BELOW 100 PERCENT OF THE POVERTY LEVEL                3142 non-null float64
# 100 TO 149 PERCENT OF THE POVERTY LEVEL               3142 non-null float64
# AT OR ABOVE 150 PERCENT OF THE POVERTY LEVEL          3142 non-null float64
# HOUSEHOLDER LIVED IN OWNER-OCCUPIED HOUSING UNITS     3142 non-null float64
# HOUSEHOLDER LIVED IN RENTER-OCCUPIED HOUSING UNITS    3142 non-null float64
# LABOR_FORCE_PARTICIPATION_RATE                        3220 non-null float64
# LAB_16-19                                             3220 non-null object
# LAB_20-24                                             3220 non-null object
# LAB_25-29                                             3220 non-null float64
# LAB_30-34                                             3220 non-null float64
# LAB_35-44                                             3220 non-null float64
# LAB_45-54                                             3220 non-null object
# LAB_55-59                                             3220 non-null float64
# LAB_60-64                                             3220 non-null float64
# LAB_65-74                                             3220 non-null float64
# LAB_OVER75                                            3220 non-null float64
# EMPLOYMENT/POPULATION_RATIO                           3220 non-null float64
# EMP_16-19                                             3220 non-null object
# EMP_20-24                                             3220 non-null object
# EMP_25-29                                             3220 non-null float64
# EMP_30-34                                             3220 non-null float64
# EMP_35-44                                             3220 non-null float64
# EMP_45-54                                             3220 non-null object
# EMP_55-59                                             3220 non-null float64
# EMP_60-64                                             3220 non-null float64
# EMP_65-74                                             3220 non-null float64
# EMP_OVER75                                            3220 non-null float64
# UNEMPLOYMENT_RATE                                     3220 non-null float64
# UNEMP_16-19                                           3220 non-null object
# UNEMP_20-24                                           3220 non-null object
# UNEMP_25-29                                           3220 non-null object
# UNEMP_30-34                                           3220 non-null float64
# UNEMP_35-44                                           3220 non-null float64
# UNEMP_45-54                                           3220 non-null object
# UNEMP_55-59                                           3220 non-null float64
# UNEMP_60-64                                           3220 non-null float64
# UNEMP_65-74                                           3220 non-null object
# UNEMP_OVER75                                          3220 non-null object
# dtypes: float64(80), object(19)
# memory usage: 2.5+ MB

# %%
data
# Out:
#        POPULATION  AGE15_19  AGE20_24  AGE25_29  AGE30_34  AGE55_59  AGE60_64  \
# 0         55200.0       7.0       6.0       6.6       6.2       7.5       4.9
# 1        208107.0       6.1       5.2       5.7       5.5       6.9       7.1
# 2         25782.0       5.6       6.4       7.2       7.0       6.4       6.4
# 3         22527.0       6.7       6.6       6.9       6.7       6.6       5.4
# 4         57645.0       6.4       5.5       5.9       5.9       6.8       6.3
# ...           ...       ...       ...       ...       ...       ...       ...
# 3216       8771.0       3.9       6.2       6.0       5.7       7.3       7.5
# 3217      22993.0       8.1       7.7       6.6       5.5       8.0       5.8
# 3218      34149.0       6.8       6.9       6.2       5.3       6.6       7.5
# 3219      36439.0       6.5       6.3       5.9       5.4       7.8       6.2
# 3220  322903030.0       6.6       6.9       7.1       6.7       6.7       6.1
#
#        TOTAL_MALE  TOTAL_FEMALE          GEO_ID  ...  UNEMP_16-19  \
# 0         26874.0       28326.0  0500000US01001  ...         14.2
# 1        101188.0      106919.0  0500000US01003  ...         13.5
# 2         13697.0       12085.0  0500000US01005  ...         27.2
# 3         12152.0       10375.0  0500000US01007  ...         30.0
# 4         28434.0       29211.0  0500000US01009  ...         21.5
# ...           ...           ...             ...  ...          ...
# 3216       4332.0        4439.0  0500000US72147  ...          0.0
# 3217      11169.0       11824.0  0500000US72149  ...         64.7
# 3218      16541.0       17608.0  0500000US72151  ...         70.1
# 3219      17475.0       18964.0  0500000US72153  ...         56.3
# 3220  158984190.0   163918840.0       0100000US  ...         18.9
#
#       UNEMP_20-24  UNEMP_25-29  UNEMP_30-34  UNEMP_35-44  UNEMP_45-54  \
# 0            12.7          3.6          3.7          3.6          2.4
# 1             9.7          8.6          2.2          2.4          4.4
# 2            11.9         20.3         14.1          9.4          5.4
# 3            19.1          8.8         16.8          5.0          3.7
# 4             8.6          2.9          2.3          4.2          3.1
# ...           ...          ...          ...          ...          ...
# 3216         11.6         21.1         11.1         25.9          5.9
# 3217         56.3         33.1         20.8         11.2         11.4
# 3218         40.0         19.7         25.1         31.1         15.9
# 3219         44.3         19.4         24.3         16.7         17.6
# 3220         10.5          6.8          5.5          4.6          4.3
#
#       UNEMP_55-59  UNEMP_60-64 UNEMP_65-74 UNEMP_OVER75
# 0             1.4          3.2         1.5          0.0
# 1             1.4          2.0         3.2          2.6
# 2             3.4          1.2         3.0          9.2
# 3             0.6          1.9         4.5          0.0
# 4             2.5          3.0         2.4          0.0
# ...           ...          ...         ...          ...
# 3216         14.6         26.9         0.0            -
# 3217         13.9          4.4         0.0          0.0
# 3218         15.1         24.4         0.0          0.0
# 3219         20.4         11.7         0.0          0.0
# 3220          4.1          3.7         3.5          3.5
#
# [3221 rows x 99 columns]

# %%
data.to_csv('final_data_county.csv')
